# %%
import tensorflow as tf
import os
import pickle
import numpy as np


CIFAR_DIR = ".\deep_learn\cifar-10-batches-py"
print(os.listdir(CIFAR_DIR))
# Out:
# ['.ipynb_checkpoints', 'batches.meta', 'data_batch_1', 'data_batch_2', 'data_batch_3', 'data_batch_4', 'data_batch_5', 'readme.html', 'test_batch']

# %%
def load_data(filename):
    """read data from data file."""
    with open(filename, 'rb') as f:
        data = pickle.load(f, encoding='bytes')
        return data[b'data'], data[b'labels']

# tensorflow.Dataset.
class CifarData:
    def __init__(self, filenames, need_shuffle):
        all_data = []
        all_labels = []
        for filename in filenames:
            data, labels = load_data(filename)
            all_data.append(data)
            all_labels.append(labels)
        self._data = np.vstack(all_data)
        self._data = self._data
        self._labels = np.hstack(all_labels)
        print(self._data.shape)
        print(self._labels.shape)
        
        self._num_examples = self._data.shape[0]
        self._need_shuffle = need_shuffle
        self._indicator = 0
        if self._need_shuffle:
            self._shuffle_data()
            
    def _shuffle_data(self):
        # [0,1,2,3,4,5] -> [5,3,2,4,0,1]
        p = np.random.permutation(self._num_examples)
        self._data = self._data[p]
        self._labels = self._labels[p]
    
    def next_batch(self, batch_size):
        """return batch_size examples as a batch."""
        end_indicator = self._indicator + batch_size
        if end_indicator > self._num_examples:
            if self._need_shuffle:
                self._shuffle_data()
                self._indicator = 0
                end_indicator = batch_size
            else:
                raise Exception("have no more examples")
        if end_indicator > self._num_examples:
            raise Exception("batch size is larger than all examples")
        batch_data = self._data[self._indicator: end_indicator]
        batch_labels = self._labels[self._indicator: end_indicator]
        self._indicator = end_indicator
        return batch_data, batch_labels

train_filenames = [os.path.join(CIFAR_DIR, 'data_batch_%d' % i) for i in range(1, 6)]
test_filenames = [os.path.join(CIFAR_DIR, 'test_batch')]

train_data = CifarData(train_filenames, True)
test_data = CifarData(test_filenames, False)
# Out:
# (50000, 3072)
# (50000,)
# (10000, 3072)
# (10000,)

# %%
x = tf.placeholder(tf.float32, [None, 3072])
y = tf.placeholder(tf.int64, [None])
# [None], eg: [0,5,6,3]
x_image = tf.reshape(x, [-1, 3, 32, 32])
# 32*32
x_image = tf.transpose(x_image, perm=[0, 2, 3, 1])
data_aug_1 = tf.image.random_flip_left_right(x_image)
data_aug_2 = tf.image.random_brightness(data_aug_1, max_delta=63)
data_aug_3 = tf.image.random_contrast(data_aug_2, lower=0.2, upper=1.8)

normal_data_aug_3 = data_aug_3 / 127.5 - 1

# conv1: 神经元图， feature_map, 输出图像
conv1_1 = tf.layers.conv2d(normal_data_aug_3,
                           32, # output channel number
                           (3,3), # kernel size
                           padding = 'same',
                           activation = tf.nn.relu,
                           name = 'conv1_1')
conv1_2 = tf.layers.conv2d(conv1_1,
                           32, # output channel number
                           (3,3), # kernel size
                           padding = 'same',
                           activation = tf.nn.relu,
                           name = 'conv1_2')

# 16 * 16
pooling1 = tf.layers.max_pooling2d(conv1_2,
                                   (2, 2), # kernel size
                                   (2, 2), # stride
                                   name = 'pool1')


conv2_1 = tf.layers.conv2d(pooling1,
                           32, # output channel number
                           (3,3), # kernel size
                           padding = 'same',
                           activation = tf.nn.relu,
                           name = 'conv2_1')
conv2_2 = tf.layers.conv2d(conv2_1,
                           32, # output channel number
                           (3,3), # kernel size
                           padding = 'same',
                           activation = tf.nn.relu,
                           name = 'conv2_2')
# 8 * 8
pooling2 = tf.layers.max_pooling2d(conv2_2,
                                   (2, 2), # kernel size
                                   (2, 2), # stride
                                   name = 'pool2')

conv3_1 = tf.layers.conv2d(pooling2,
                           32, # output channel number
                           (3,3), # kernel size
                           padding = 'same',
                           activation = tf.nn.relu,
                           name = 'conv3_1')
conv3_2 = tf.layers.conv2d(conv3_1,
                           32, # output channel number
                           (3,3), # kernel size
                           padding = 'same',
                           activation = tf.nn.relu,
                           name = 'conv3_2')
# 4 * 4 * 32
pooling3 = tf.layers.max_pooling2d(conv3_2,
                                   (2, 2), # kernel size
                                   (2, 2), # stride
                                   name = 'pool3')
# [None, 4 * 4 * 32]
flatten = tf.layers.flatten(pooling3)
y_ = tf.layers.dense(flatten, 10)

loss = tf.losses.sparse_softmax_cross_entropy(labels=y, logits=y_)
# y_ -> sofmax
# y -> one_hot
# loss = ylogy_

# indices
predict = tf.argmax(y_, 1)
# [1,0,1,1,1,0,0,0]
correct_prediction = tf.equal(predict, y)
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float64))

with tf.name_scope('train_op'):
    train_op = tf.train.AdamOptimizer(1e-3).minimize(loss)
# Out:
# WARNING:tensorflow:From D:\Anaconda\lib\site-packages\tensorflow\python\ops\control_flow_ops.py:3632: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From <ipython-input-3-899a64c52b86>:20: conv2d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.conv2d instead.
# WARNING:tensorflow:From <ipython-input-3-899a64c52b86>:32: max_pooling2d (from tensorflow.python.layers.pooling) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.max_pooling2d instead.
# WARNING:tensorflow:From <ipython-input-3-899a64c52b86>:71: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From <ipython-input-3-899a64c52b86>:72: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# WARNING:tensorflow:From D:\Anaconda\lib\site-packages\tensorflow\python\ops\losses\losses_impl.py:209: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
def variable_summary(var, name):
    """Constructs summary for statistics of a variable"""
    with tf.name_scope(name):
        mean = tf.reduce_mean(var)
        with tf.name_scope('stddev'):
            stddev = tf.sqrt(tf.reduce_mean(tf.square(var - mean)))
        tf.summary.scalar('mean', mean)
        tf.summary.scalar('stddev', stddev)
        tf.summary.scalar('min', tf.reduce_min(var))
        tf.summary.scalar('max', tf.reduce_max(var))
        tf.summary.histogram('histogram', var)

with tf.name_scope('summary'):
    variable_summary(conv1_1, 'conv1_1')
    variable_summary(conv1_2, 'conv1_2')
    variable_summary(conv2_1, 'conv2_1')
    variable_summary(conv2_2, 'conv2_2')
    variable_summary(conv3_1, 'conv3_1')
    variable_summary(conv3_2, 'conv3_2')

    
    
loss_summary = tf.summary.scalar('loss', loss)
accuracy_summary = tf.summary.scalar('accuracy', accuracy)

# source_image = (x_image + 1) * 127.5
inputs_summary = tf.summary.image('inputs_image', normal_data_aug_3)

megred_summary = tf.summary.merge_all()
megred_summary_test = tf.summary.merge([loss_summary, accuracy_summary])

LOG_DIR = '.'
run_label = 'run_vgg_tensorboard_fine_tune'
run_dir = os.path.join(LOG_DIR, run_label)
if not os.path.exists(run_dir):
    os.mkdir(run_dir)
train_log_dir = os.path.join(run_dir, 'train')
test_log_dir = os.path.join(run_dir, 'test')

if not os.path.exists(train_log_dir):
    os.mkdir(train_log_dir)

if not os.path.exists(test_log_dir):
    os.mkdir(test_log_dir)

# %%
model_dir = os.path.join(run_dir, 'model')
if not os.path.exists(model_dir):
    os.mkdir(model_dir)
saver = tf.train.Saver()
model_name = 'ckp-1000'
model_path = os.path.join(model_dir, model_name)

# %%
init = tf.global_variables_initializer()
batch_size = 20
train_steps = 1000
test_steps = 100

output_summary_every_steps = 100
output_model_every_steps = 100

# train 10k: 73.4%
with tf.Session() as sess:
    sess.run(init)
    train_writer = tf.summary.FileWriter(train_log_dir, sess.graph)
    test_writer = tf.summary.FileWriter(test_log_dir)
    
    fixed_test_batch_data, fixed_test_batch_labels = test_data.next_batch(batch_size)
    
    if os.path.exists(model_path + '.index'):
        saver.restore(sess, model_path)
        print('model restore from {}'.format(model_path))
    else:
        print('model {} does not exist'.format(model_path))
    
    for i in range(train_steps):
        batch_data, batch_labels = train_data.next_batch(batch_size)
        eval_ops = [loss, accuracy, train_op]
        should_output_summary = ((i+1) % output_summary_every_steps == 0)
        if should_output_summary:
            eval_ops.append(megred_summary)
        
        eval_ops_results = sess.run(
            eval_ops,
            feed_dict={
                x: batch_data,
                y: batch_labels})
        loss_val, acc_val = eval_ops_results[0:2]
        if should_output_summary:
            train_summary_str = eval_ops_results[-1]
            train_writer.add_summary(train_summary_str, i+1)
            test_summarys_str = sess.run([megred_summary_test],
                                         feed_dict={
                                             x: fixed_test_batch_data,
                                             y: fixed_test_batch_labels,    
                                         })[0]
            test_writer.add_summary(test_summarys_str, i+1)
        if (i+1) % 100 == 0:
            print('[Train] Step: %d, loss: %4.5f, acc: %4.5f' 
                  % (i+1, loss_val, acc_val))
        if (i+1) % 1000 == 0:
            test_data = CifarData(test_filenames, False)
            all_test_acc_val = []
            for j in range(test_steps):
                test_batch_data, test_batch_labels \
                    = test_data.next_batch(batch_size)
                test_acc_val = sess.run(
                    [accuracy],
                    feed_dict = {
                        x: test_batch_data, 
                        y: test_batch_labels
                    })
                all_test_acc_val.append(test_acc_val)
            test_acc = np.mean(all_test_acc_val)
            print('[Test ] Step: %d, acc: %4.5f' % (i+1, test_acc))
        if (i+1) % output_model_every_steps == 0:
            saver.save(sess, os.path.join(model_dir, 'ckp-{}'.format(i+1)))
            print('model saved to ckp-{}'.format(i+1))
# Out:
# WARNING:tensorflow:From D:\Anaconda\lib\site-packages\tensorflow\python\training\saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from .\run_vgg_tensorboard_fine_tune\model\ckp-1000
# model restore from .\run_vgg_tensorboard_fine_tune\model\ckp-1000
# [Train] Step: 100, loss: 0.67190, acc: 0.80000
# model saved to ckp-100
# [Train] Step: 200, loss: 1.24250, acc: 0.50000
# model saved to ckp-200
# [Train] Step: 300, loss: 1.02924, acc: 0.70000
# model saved to ckp-300
# [Train] Step: 400, loss: 0.85059, acc: 0.60000
# model saved to ckp-400
# [Train] Step: 500, loss: 1.03535, acc: 0.65000
# model saved to ckp-500
# [Train] Step: 600, loss: 0.62124, acc: 0.80000
# WARNING:tensorflow:From D:\Anaconda\lib\site-packages\tensorflow\python\training\saver.py:966: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# model saved to ckp-600
# [Train] Step: 700, loss: 1.08825, acc: 0.50000
# model saved to ckp-700
# [Train] Step: 800, loss: 1.21703, acc: 0.70000
# model saved to ckp-800
# [Train] Step: 900, loss: 0.86143, acc: 0.75000
# model saved to ckp-900
# [Train] Step: 1000, loss: 0.53356, acc: 0.85000
# (10000, 3072)
# (10000,)
# [Test ] Step: 1000, acc: 0.70200
# model saved to ckp-1000
# [Train] Step: 1100, loss: 0.47412, acc: 0.90000
# model saved to ckp-1100
# [Train] Step: 1200, loss: 0.70426, acc: 0.70000
# model saved to ckp-1200
# [Train] Step: 1300, loss: 1.03091, acc: 0.65000
# model saved to ckp-1300
# [Train] Step: 1400, loss: 0.78186, acc: 0.70000
# model saved to ckp-1400
# [Train] Step: 1500, loss: 0.44316, acc: 0.70000
# model saved to ckp-1500
# [Train] Step: 1600, loss: 0.42609, acc: 0.85000
# model saved to ckp-1600
# [Train] Step: 1700, loss: 1.30031, acc: 0.50000
# model saved to ckp-1700
# [Train] Step: 1800, loss: 0.65827, acc: 0.75000
# model saved to ckp-1800
# [Train] Step: 1900, loss: 0.75174, acc: 0.70000
# model saved to ckp-1900
# [Train] Step: 2000, loss: 1.02019, acc: 0.55000
# (10000, 3072)
# (10000,)
# [Test ] Step: 2000, acc: 0.69700
# model saved to ckp-2000
# [Train] Step: 2100, loss: 0.68493, acc: 0.65000
# model saved to ckp-2100
# [Train] Step: 2200, loss: 1.02333, acc: 0.60000
# model saved to ckp-2200
# [Train] Step: 2300, loss: 1.26256, acc: 0.55000
# model saved to ckp-2300
# [Train] Step: 2400, loss: 1.59893, acc: 0.50000
# model saved to ckp-2400
# [Train] Step: 2500, loss: 0.98093, acc: 0.65000
# model saved to ckp-2500
# [Train] Step: 2600, loss: 1.04283, acc: 0.55000
# model saved to ckp-2600
# [Train] Step: 2700, loss: 0.65814, acc: 0.70000
# model saved to ckp-2700
# [Train] Step: 2800, loss: 0.66092, acc: 0.65000
# model saved to ckp-2800
# [Train] Step: 2900, loss: 0.57671, acc: 0.70000
# model saved to ckp-2900
# [Train] Step: 3000, loss: 0.83631, acc: 0.65000
# (10000, 3072)
# (10000,)
# [Test ] Step: 3000, acc: 0.69400
# model saved to ckp-3000
# [Train] Step: 3100, loss: 1.03474, acc: 0.70000
# model saved to ckp-3100
# [Train] Step: 3200, loss: 1.14068, acc: 0.60000
# model saved to ckp-3200
# [Train] Step: 3300, loss: 0.55361, acc: 0.80000
# model saved to ckp-3300
# [Train] Step: 3400, loss: 0.44465, acc: 0.95000
# model saved to ckp-3400
# [Train] Step: 3500, loss: 0.86207, acc: 0.70000
# model saved to ckp-3500
# [Train] Step: 3600, loss: 0.79789, acc: 0.65000
# model saved to ckp-3600
# [Train] Step: 3700, loss: 0.48278, acc: 0.80000
# model saved to ckp-3700
# [Train] Step: 3800, loss: 1.47669, acc: 0.50000
# model saved to ckp-3800
# [Train] Step: 3900, loss: 0.94901, acc: 0.60000
# model saved to ckp-3900
# [Train] Step: 4000, loss: 0.57193, acc: 0.70000
# (10000, 3072)
# (10000,)
# [Test ] Step: 4000, acc: 0.70350
# model saved to ckp-4000
# [Train] Step: 4100, loss: 0.72566, acc: 0.75000
# model saved to ckp-4100
# [Train] Step: 4200, loss: 1.01394, acc: 0.60000
# model saved to ckp-4200
# [Train] Step: 4300, loss: 0.83000, acc: 0.75000
# model saved to ckp-4300
# [Train] Step: 4400, loss: 0.35430, acc: 0.90000
# model saved to ckp-4400
# [Train] Step: 4500, loss: 0.95709, acc: 0.65000
# model saved to ckp-4500
# [Train] Step: 4600, loss: 0.55340, acc: 0.80000
# model saved to ckp-4600
# [Train] Step: 4700, loss: 1.16406, acc: 0.50000
# model saved to ckp-4700
# [Train] Step: 4800, loss: 0.74628, acc: 0.80000
# model saved to ckp-4800
# [Train] Step: 4900, loss: 0.90320, acc: 0.70000
# model saved to ckp-4900
# [Train] Step: 5000, loss: 1.37298, acc: 0.50000
# (10000, 3072)
# (10000,)
# [Test ] Step: 5000, acc: 0.70600
# model saved to ckp-5000
# [Train] Step: 5100, loss: 0.93721, acc: 0.70000
# model saved to ckp-5100
# [Train] Step: 5200, loss: 1.73537, acc: 0.50000
# model saved to ckp-5200
# [Train] Step: 5300, loss: 0.78317, acc: 0.65000
# model saved to ckp-5300
# [Train] Step: 5400, loss: 1.21214, acc: 0.50000
# model saved to ckp-5400
# [Train] Step: 5500, loss: 0.54990, acc: 0.85000
# model saved to ckp-5500
# [Train] Step: 5600, loss: 1.03639, acc: 0.75000
# model saved to ckp-5600
# [Train] Step: 5700, loss: 0.73507, acc: 0.70000
# model saved to ckp-5700
# [Train] Step: 5800, loss: 1.24534, acc: 0.55000
# model saved to ckp-5800
# [Train] Step: 5900, loss: 0.72282, acc: 0.80000
# model saved to ckp-5900
# [Train] Step: 6000, loss: 0.84275, acc: 0.70000
# (10000, 3072)
# (10000,)
# [Test ] Step: 6000, acc: 0.70750
# model saved to ckp-6000
# [Train] Step: 6100, loss: 0.92399, acc: 0.75000
# model saved to ckp-6100
# [Train] Step: 6200, loss: 0.82863, acc: 0.75000
# model saved to ckp-6200
# [Train] Step: 6300, loss: 0.63309, acc: 0.80000
# model saved to ckp-6300
# [Train] Step: 6400, loss: 0.58162, acc: 0.85000
# model saved to ckp-6400
# [Train] Step: 6500, loss: 0.85086, acc: 0.65000
# model saved to ckp-6500
# [Train] Step: 6600, loss: 0.86836, acc: 0.70000
# model saved to ckp-6600
# [Train] Step: 6700, loss: 0.64519, acc: 0.85000
# model saved to ckp-6700
# [Train] Step: 6800, loss: 1.00890, acc: 0.70000
# model saved to ckp-6800
# [Train] Step: 6900, loss: 0.60464, acc: 0.80000
# model saved to ckp-6900
# [Train] Step: 7000, loss: 0.43917, acc: 0.85000
# (10000, 3072)
# (10000,)
# [Test ] Step: 7000, acc: 0.71750
# model saved to ckp-7000
# [Train] Step: 7100, loss: 0.53025, acc: 0.80000
# model saved to ckp-7100
# [Train] Step: 7200, loss: 1.16150, acc: 0.55000
# model saved to ckp-7200
# [Train] Step: 7300, loss: 0.82153, acc: 0.70000
# model saved to ckp-7300
# [Train] Step: 7400, loss: 0.59200, acc: 0.70000
# model saved to ckp-7400
# [Train] Step: 7500, loss: 0.78449, acc: 0.65000
# model saved to ckp-7500
# [Train] Step: 7600, loss: 1.07125, acc: 0.65000
# model saved to ckp-7600
# [Train] Step: 7700, loss: 0.62559, acc: 0.75000
# model saved to ckp-7700
# [Train] Step: 7800, loss: 0.74660, acc: 0.65000
# model saved to ckp-7800
# [Train] Step: 7900, loss: 1.19628, acc: 0.60000
# model saved to ckp-7900
# [Train] Step: 8000, loss: 0.70378, acc: 0.65000
# (10000, 3072)
# (10000,)
# [Test ] Step: 8000, acc: 0.70400
# model saved to ckp-8000
# [Train] Step: 8100, loss: 0.76440, acc: 0.80000
# model saved to ckp-8100
# [Train] Step: 8200, loss: 1.23827, acc: 0.60000
# model saved to ckp-8200
# [Train] Step: 8300, loss: 1.08072, acc: 0.60000
# model saved to ckp-8300
# [Train] Step: 8400, loss: 0.48940, acc: 0.80000
# model saved to ckp-8400
# [Train] Step: 8500, loss: 0.41241, acc: 0.85000
# model saved to ckp-8500
# [Train] Step: 8600, loss: 0.88938, acc: 0.75000
# model saved to ckp-8600
# [Train] Step: 8700, loss: 0.99558, acc: 0.50000
# model saved to ckp-8700
# [Train] Step: 8800, loss: 0.79363, acc: 0.70000
# model saved to ckp-8800
# [Train] Step: 8900, loss: 0.62093, acc: 0.80000
# model saved to ckp-8900
# [Train] Step: 9000, loss: 0.66223, acc: 0.80000
# (10000, 3072)
# (10000,)
# [Test ] Step: 9000, acc: 0.71550
# model saved to ckp-9000
# [Train] Step: 9100, loss: 0.83556, acc: 0.75000
# model saved to ckp-9100
# [Train] Step: 9200, loss: 1.36965, acc: 0.60000
# model saved to ckp-9200
# [Train] Step: 9300, loss: 0.65491, acc: 0.75000
# model saved to ckp-9300
# [Train] Step: 9400, loss: 0.37240, acc: 0.95000
# model saved to ckp-9400
# [Train] Step: 9500, loss: 0.99853, acc: 0.70000
# model saved to ckp-9500
# [Train] Step: 9600, loss: 0.65959, acc: 0.75000
# model saved to ckp-9600
# [Train] Step: 9700, loss: 0.53904, acc: 0.85000
# model saved to ckp-9700
# [Train] Step: 9800, loss: 0.78793, acc: 0.80000
# model saved to ckp-9800
# [Train] Step: 9900, loss: 0.78688, acc: 0.70000
# model saved to ckp-9900
# [Train] Step: 10000, loss: 0.46150, acc: 0.80000
# (10000, 3072)
# (10000,)
# [Test ] Step: 10000, acc: 0.71750
# model saved to ckp-10000
