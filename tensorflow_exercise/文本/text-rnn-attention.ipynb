# %%
import tensorflow as tf
import os
import sys
import numpy as np
import math
from tensorflow.python.ops.rnn import bidirectional_dynamic_rnn as bi_rnn
from tensorflow.contrib.rnn import GRUCell

tf.logging.set_verbosity(tf.logging.INFO)

# %%
## 下面高参数 10K 次 train: 99.7%, Valid: 92.7%, Test: 93.2%
def get_default_params():
    return tf.contrib.training.HParams(
        # num_embedding_size = 16,
        num_embedding_size = 32,
        # 一个句子取前50个分词
        # num_timesteps = 50,
        num_timesteps = 200,
        # num_lstm_nodes = [32, 32],
        num_lstm_nodes = [64, 64],
        num_lstm_layers = 2,
        # num_fc_nodes = 32,
        num_fc_nodes = 64,
        batch_size = 100,
        clip_lstm_grads = 1.0,
        learning_rate = 0.001,
        num_word_threshold = 10,
    )
hps = get_default_params()

seg_train_file = '.\deep_learn\sohu_seg_train_file.txt'
seg_test_file = '.\deep_learn\sohu_seg_test_file.txt'

vocab_file =  '.\deep_learn\sohu_vocab.txt'
category_file = '.\deep_learn\sohu_category.txt'
output_file = '.\deep_learn\sohu_run_text_run'
vocab_padding_file = '.\deep_learn\sohu_padding_vocab.txt'

if not os.path.exists(output_file):
    os.mkdir(output_file)

# %%
def attention(inputs, attention_size, time_major=False, return_alphas=False):
    """
    Attention mechanism layer which reduces RNN/Bi-RNN outputs with Attention vector.

    The idea was proposed in the article by Z. Yang et al., "Hierarchical Attention Networks
     for Document Classification", 2016: http://www.aclweb.org/anthology/N16-1174.
    Variables notation is also inherited from the article
    
    Args:
        inputs: The Attention inputs.
            Matches outputs of RNN/Bi-RNN layer (not final state):
                In case of RNN, this must be RNN outputs `Tensor`:
                    If time_major == False (default), this must be a tensor of shape:
                        `[batch_size, max_time, cell.output_size]`.
                    If time_major == True, this must be a tensor of shape:
                        `[max_time, batch_size, cell.output_size]`.
                In case of Bidirectional RNN, this must be a tuple (outputs_fw, outputs_bw) containing the forward and
                the backward RNN outputs `Tensor`.
                    If time_major == False (default),
                        outputs_fw is a `Tensor` shaped:
                        `[batch_size, max_time, cell_fw.output_size]`
                        and outputs_bw is a `Tensor` shaped:
                        `[batch_size, max_time, cell_bw.output_size]`.
                    If time_major == True,
                        outputs_fw is a `Tensor` shaped:
                        `[max_time, batch_size, cell_fw.output_size]`
                        and outputs_bw is a `Tensor` shaped:
                        `[max_time, batch_size, cell_bw.output_size]`.
        attention_size: Linear size of the Attention weights.
        time_major: The shape format of the `inputs` Tensors.
            If true, these `Tensors` must be shaped `[max_time, batch_size, depth]`.
            If false, these `Tensors` must be shaped `[batch_size, max_time, depth]`.
            Using `time_major = True` is a bit more efficient because it avoids
            transposes at the beginning and end of the RNN calculation.  However,
            most TensorFlow data is batch-major, so by default this function
            accepts input and emits output in batch-major form.
        return_alphas: Whether to return attention coefficients variable along with layer's output.
            Used for visualization purpose.
    Returns:
        The Attention output `Tensor`.
        In case of RNN, this will be a `Tensor` shaped:
            `[batch_size, cell.output_size]`.
        In case of Bidirectional RNN, this will be a `Tensor` shaped:
            `[batch_size, cell_fw.output_size + cell_bw.output_size]`.
    """

    if isinstance(inputs, tuple):
        # In case of Bi-RNN, concatenate the forward and the backward RNN outputs.
        inputs = tf.concat(inputs, 2)

    if time_major:
        # (T,B,D) => (B,T,D)
        inputs = tf.array_ops.transpose(inputs, [1, 0, 2])

    hidden_size = inputs.shape[2].value  # D value - hidden size of the RNN layer

    # Trainable parameters
    w_omega = tf.Variable(tf.random_normal([hidden_size, attention_size], stddev=0.1))
    b_omega = tf.Variable(tf.random_normal([attention_size], stddev=0.1))
    u_omega = tf.Variable(tf.random_normal([attention_size], stddev=0.1))

    with tf.name_scope('v'):
        # Applying fully connected layer with non-linear activation to each of the B*T timestamps;
        #  the shape of `v` is (B,T,D)*(D,A)=(B,T,A), where A=attention_size
        v = tf.tanh(tf.tensordot(inputs, w_omega, axes=1) + b_omega)

    # For each of the timestamps its vector of size A from `v` is reduced with `u` vector
    vu = tf.tensordot(v, u_omega, axes=1, name='vu')  # (B,T) shape
    alphas = tf.nn.softmax(vu, name='alphas')         # (B,T) shape

    # Output of (Bi-)RNN is reduced with attention vector; the result has (B,D) shape
    output = tf.reduce_sum(inputs * tf.expand_dims(alphas, -1), 1)

    if not return_alphas:
        return output
    else:
        return output, alphas


# api sentence_to_id的实现
class Vocab:
    def __init__(self, filename, num_word_threshold):
        self._word_to_id = {}
        self._unk = -1
        self._padding = 1
        self._num_word_threshold = num_word_threshold
        self._read_dict(filename)
    
    def _read_dict(self, filename):
        with open(filename, 'r') as f:
            lines = f.readlines()
        for line in lines:
            word, frequency = line.strip('\r\n').split('\t')
            # 第一行为<UNK> 用于test出现train没有出现的词
            # 第二行为<PADDING> 用于过短进行padding
            frequency = int(frequency)
            if frequency < self._num_word_threshold:
                continue
            idx = len(self._word_to_id)
            if word == '<UNK>':
                self._unk = idx
            self._word_to_id[word] = idx
    def word_to_id(self, word):
        return self._word_to_id.get(word, self._unk)
    
    @property
    def unk(self):
        return self._unk
    
    @property
    def padding(self):
        return self._padding
    
    def size(self):
        return len(self._word_to_id)
    
    def sentence_to_id(self, sentence):
        # 分词后的句子用空格来隔开每一个词语,这里每一句话里的分词用id来表示
        word_ids = [self.word_to_id(cur_word) for cur_word in sentence.split()]
        return word_ids
# keras中imdb中使用0作padding, 未出现过的词用2代替
class CategoryDict:
    def __init__(self, filename):
        self._category_to_id = {}
        with open(filename, 'r') as f:
            lines = f.readlines()
        for line in lines:
            category = line.strip('\r\n')
            idx = len(self._category_to_id)
            self._category_to_id[category] = idx
            
    def size(self):
        return len(self._category_to_id)
    
    def category_to_id(self, category):
        if not category in self._category_to_id:
            print(self._category_to_id)
            raise Exception("{} is not in our category".format(category))
            
        return self._category_to_id[category]
          
vocab = Vocab(vocab_padding_file, hps.num_word_threshold)
vocab_size = vocab.size()
print(vocab.word_to_id('<UNK>')) # 0
print(vocab.word_to_id('<PADDING>')) # 1
print('unk', vocab.unk)
print('padding', vocab.padding)
tf.logging.info('vocab_size: {}'.format(vocab_size))
category_vocab = CategoryDict(category_file)
num_classes = category_vocab.size()
tf.logging.info('category_size: {}'.format(num_classes))
test_str = '女人'
tf.logging.info('id:{}'.format(category_vocab.category_to_id(test_str)))
# Out:
# 0
# 1
# unk 0
# padding 1
# INFO:tensorflow:vocab_size: 85429
# INFO:tensorflow:category_size: 12
# INFO:tensorflow:id:11

# %%
# 
class TextDataSet:
    def __init__(self, filename, vocab, category_vocab, num_timesteps):
        self._vocab = vocab
        self._category_vocab = category_vocab
        self._num_timesteps = num_timesteps
        
        self._inputs = []
        self._outputs = []
        
        self._indicator = 0
        self._parse_file(filename)
        
    def _parse_file(self, filename):
        tf.logging.info('Loading data from {}'.format(filename))
        lines = 0
        import re
        if re.findall('train', filename):
            with open(filename, 'r') as f:
                lines = f.readlines()
        elif re.findall('test', filename):
            with open(filename, 'r', encoding='utf-8-sig') as f:
                lines = f.readlines()  
        for line in lines:
            label, content = line.strip('\r\n').split('\t')
            id_label = self._category_vocab.category_to_id(label)
            id_words = self._vocab.sentence_to_id(content)
            
            id_words = id_words[0: self._num_timesteps]
            padding_num = self._num_timesteps - len(id_words)
            
            id_words = id_words + [
                self._vocab.padding for i in range(padding_num)]
            self._inputs.append(id_words)
            self._outputs.append(id_label)
        
        self._inputs = np.asarray(self._inputs, dtype=np.int32)
        self._outputs = np.asarray(self._outputs, dtype=np.int32)
        self._random_shuffle()
        
    def _random_shuffle(self):
        p = np.random.permutation(len(self._inputs))
        self._inputs = self._inputs[p]
        self._outputs = self._outputs[p]
    
    def next_batch(self, batch_size):
        end_indicator = self._indicator + batch_size
        if end_indicator > len(self._inputs):
            self._random_shuffle()
            self._indicator = 0
            end_indicator = batch_size
        if end_indicator > len(self._inputs):
            raise Exception("batch size: {} is too large".format(batch_size))
        
        batch_inputs = self._inputs[self._indicator: end_indicator]
        batch_output = self._outputs[self._indicator: end_indicator]
        self._indicator = end_indicator
        return batch_inputs, batch_output

train_dataset = TextDataSet(seg_train_file, vocab, category_vocab, hps.num_timesteps)
test_dataset = TextDataSet(seg_test_file, vocab, category_vocab, hps.num_timesteps)
# Out:
# INFO:tensorflow:Loading data from .\deep_learn\sohu_seg_train_file.txt
# INFO:tensorflow:Loading data from .\deep_learn\sohu_seg_test_file.txt

# %%
print(train_dataset.next_batch(5))
# 因为next_batch == 2 ,输出为
# 只选择句子前50个分词, 输出为2*50的矩阵,第一个为句子分词的索引id, 第二个为分类的索引id
# Out:
# (array([[    8,   326,     3,  5006,   120,  4673, 18872,   816,     8,
#          6155, 71263,    52,    29,     0,  9178,    51,    27,   110,
#           129,    35,   110,   168,   181,    63,    79,    72,    26,
#             2,   456, 27886,  1687,   931,    63,    69,    54,    60,
#           129,    54,    69,   330,   129,   126,    72,   156,   126,
#            35,    79,    72,     2,   122,  4690,     3,    82,   148,
#           239,     3, 25267, 22801,     6, 14604,  1240,     2,   678,
#           585, 38310,     3,  3088,  1108,     7,    18,   948,    29,
#             0,  9178,  1090,     3, 17612, 59812,     4,  4623,  3170,
#            44,   326,     2,  2638, 24308, 10143,   191,     8,   924,
#         13340, 36985,   209,    52,   835,     3,   326,  8051,    51,
#             2,   727,     3,    11,  3170,  2213,   351,    64,   326,
#           881,    36,   337,  6808,     4,    49,   461,   125,    48,
#           670,    61,    50,     2,   697,     2,    11,    52,  1318,
#           134,    79,    54,   181,    54,     3, 17967,    51,   306,
#            42,    37,    37,     2,  1457, 16687,     3,  4505,   106,
#            63,   229,    63,    15,  8829,  8053,  1891,   148,    28,
#             3, 56094,  3741,     2,   976,   326,    36,  5134,  4414,
#            15,   753, 73988,     3,  1831,  1008,     3, 10427,    15,
#          4673, 15094,     2,   258,    11,   122,  1457, 51878,     3,
#           317,     4,  4673,  1831, 13977,     3,   326,  1634,   421,
#         19978,  3698,     0,     2,  4280,  5304,  6150,     2,  1673,
#           357,  1371],
#        [10291,     0, 37812,   180,   223,    93,  1323,   422,  2707,
#         10291,     0,   552,  9744,  9267, 35587,  1286,  1414,    70,
#         29648,  4446,   894,     2,   444,    45,   894, 11618,   407,
#           911,     7,    16,    62,     2,    82,    45, 82257,   357,
#           894,     4,  2707, 25353,  1572,  4628,   146, 18006, 67831,
#          6538,   894,     3,   190, 54388, 11854,     2, 10291,     0,
#           352,    45,     8,   185,    19,    47,     7,  2260,   990,
#             4,    12,   357,   894,   118,  4658,  6536,     2,   125,
#         11749,     3,  3001,   350,    22,    45,  8720,     4,    13,
#            32,    50,     4,  2707,  4271,     0,   146,     0,    50,
#             2,   391, 10291,     3,   797,  1187,    74,   217,   658,
#             2,   315,    70,   613,   412,    29,    23,   859,     3,
#           377,     6,  1836,  7942,   552,     4,   603,    10,     5,
#             5,    16,    30,   574,     2, 35587,  1425,   990, 10291,
#             6,  8981,   352,     4,   185,    16,    47,    10,    10,
#            77,     2,  2707,   223,   405,   974,    70,    45, 12168,
#             2,    10,     5,     5,    24,    30,   780,    70,   253,
#          1278,     4,  3414,     2,  2707,   223,  4334,  1139,    82,
#            37,  2087,     4,   185,    16,    47,     3,  1139,   983,
#           488,     7,    18,    62,     2,   191,    16,   114, 11220,
#           983,   488,     7,     7,    62,     4,     0,    50,     2,
#           391, 10291,   253,     8,   408,    70,   723, 67108,  1059,
#             3,   400],
#        [  646,   301,  1324,  1056,   687,  2939,    89,   450,  1701,
#             2,   308,  2939,     3,    89,   839,  8413,     4,  7714,
#           798,     3,   516,   492,     2,   308,    10,     5,     5,
#            25,    30,  5511,   301,  1628,   467,     7,    20,    17,
#            10, 23311,     2,  2939,  8237,   467,     7,    20,     5,
#            24,  7191,     2,   363,   137,   259,    39,   300,     3,
#           249,   301,    67,    15,  2732,    96,  5511,   301,     0,
#             4,   725,     2,    44,   970, 31604,     3,    11,     2,
#           308,   301,  1324,     3,  1056,   445,   757,   319, 12183,
#             2,   301,  1324,  3607,   247,  4066,     2,   137,  2939,
#            89,    36,     3,    12, 75224,    13,     4,   199,   153,
#          5367,  2939,  3440,     3,   336,     2,  5367,   301,  2648,
#             3,  2831,     2,  3667,     9,  2939,     3,    97,    96,
#            89,     4,   301,  1324,    75,    50,    11,    38,   317,
#           301,   555,     3, 13375,     2,    11,    38,  1800,     3,
#          8235,     4,   179,  2142,  1815,  1800,     3, 17474,    15,
#         22950,     2,    75,   268,   878,   509,   301,  7755,    15,
#          2022,  4031,     4,   725,     2,   308,  1838,   301,  1324,
#             3,   356,  1020,    37,  1412,     2,  2149,  3227,     2,
#           922, 19556,     2,  1122,  8439,     2,  1335,  3317,     2,
#          1158,  1019,   878,     4,   165,   199,  1091,     2,  1097,
#          7915,     3,   375,     4,    64,    67,   264,   153,   512,
#             2,   301],
#        [   10,     5,     5,    21,    30,    12,   117,  6833,    13,
#          1291,  8515,  9093,  5366,    27,  3189,    26,     0,    10,
#             5,     5,    21,    30,    12,   117,  6833,    13,  1291,
#          8515,  9093,  5366,   298,    87,    97,    90,     3,   178,
#          1844,   589,    15,   388,  1075,   117,  6833,  1291,     3,
#           356,    44,    67,   472,     2,   194,   249,  2103,   178,
#          1711,    85,    85,    52, 25758,    51,  4064,     3,    10,
#             5,     5,    21,    30,    12,   117,  6833,  1291,  8515,
#            13,   177,     7,     5,    47,    10,    17,    77,   864,
#             8,  6204, 34445, 20235,     4,   112,   117, 12049,    12,
#          4223, 13858,    13,     6,   112,    12, 11960, 31120,     3,
#          9502,    13,     6,   112,    12, 28800,    13,     6,   112,
#            12,  6894,  1291,    13,     6,   660,    12,  4181, 18620,
#            13,     6,   660,    12, 17846,  4540,    13,    55,    43,
#          8284,   117,  6833,  1291,    45,     8, 34445,  1860,  2113,
#          6657,     4, 26398,     2,    88,  3626,  1090,    41,   452,
#             3,   220,   553,  2170,  1127,    12,  1523,     6,  2055,
#             6,   835,    13,     3, 12488,     2,    43,     3,  1291,
#            67,   771,    41, 17733,  1291,   198,  3023,     4,    31,
#           976,     3,   334,     6,  2213,  2636,  1766,  1029,     2,
#             8,    81,   220,   561, 10896,  6301,     3,   470,     2,
#           351,  1075,    12,    23,    43,  1020,     3,   637,   553,
#           356,    13],
#        [ 5106, 64623,   358,     0,   301,  3256,    18,    47,    10,
#            16,     0,   133,   939,   132,  2259, 13218,    18,    47,
#            19,  3617,    27,    95,     0,    26,   454,  3407,   301,
#          2297,  5472,  2408,  4706,     2,   194,  5106, 33455,     3,
#         13218,   358,    12,  3730,  8860,    13,     0,     3,  2693,
#             2,    45,   177,    18,    47,    10,    16,    77,   606,
#         21884,     4, 13218,    85,    85,     0,  3256,  3730,  1463,
#            17,    24,    25,  1245,     2,   194,    94,   110,   330,
#         64632,   990,     2,   746, 15686,     4,  4539,    46,    18,
#            47,    17,     5,    77,     2,  2693, 33506,    41,    14,
#            10,    16,    77,     6,    10,    25,    77,     6,    10,
#            19,    77,     6,    10,    24,    77,    64, 13218,  4729,
#             3,   147,    41,     7,    10,    14,    21,     5,     2,
#            10,    18,    77,     6,    17,     5,    77, 13218,  4729,
#             3,   147,    11,     7,    21,    14,    16,     5,     4,
#            25,    47,   489, 61871, 19711,     4,  2693,  3730,  2530,
#           535,     7,   525,     2,     8,     0,  1730,  4625,  3856,
#            71,  3168, 13218,     4,    10,     5,     5,    18,    30,
#            25,    47,    10,    10,    77,     2,   194,  5106, 33455,
#             3, 13218,    85,    85,     0,  3730,   301, 21510, 25187,
#             2,    82,   177,   764,   301,  6052, 33455,     2,    53,
#            22,    11,  3407, 41415,   301,  3256,     4,   173,    21,
#            94,  1157]]), array([11,  8,  3,  2,  3]))

# %%
def create_model(hps, vocab_size, num_classes):
    # 取一个句子的前50个分词, num_classes为固定的50个分词
    num_timesteps = hps.num_timesteps
    # 训练批次大小
    batch_size = hps.batch_size
    # 输入为[批次的大小,50]
    inputs = tf.placeholder(tf.int32, (batch_size, num_timesteps))
    # 输出为[批次的大小,]
    outputs = tf.placeholder(tf.int32, (batch_size, ))
    # dropout的使用
    keep_prob = tf.placeholder(tf.float32, name='keep_prob')
    # 保存训练到哪一步
    global_step = tf.Variable(
        tf.zeros([], tf.int64), name='global_step', trainable=False)
    
    seq_len_ph = tf.placeholder(tf.int32, [None], name='seq_len_ph')

    # 随机化embedding 编码
    embedding_initializer = tf.random_uniform_initializer(-1.0, 1.0)
    with tf.variable_scope(
        'embedding', initializer=embedding_initializer):
        embeddings = tf.get_variable(
            'embedding',
            [vocab_size+2, hps.num_embedding_size],
            tf.float32)
        print('embeddings', embeddings)# (85430, 32)
        # 把输入的分词中的id -> embedding编码形式
        # ex [1, 10, 7] -> [embeddings[1], embeddings[10], embeddings[7]]
        embed_inputs = tf.nn.embedding_lookup(embeddings, inputs) # (100, 200, 32)
        print('embed_inputs', embed_inputs)
    # (Bi-)RNN layser
    
    
    
    
    rnn_outputs, _ = bi_rnn(GRUCell(64), GRUCell(64),
                            inputs=embed_inputs, sequence_length=seq_len_ph, dtype=tf.float32)
    # [batch_size, cell_fw.output_size + cell_bw.output_size]
    print('rnn_outputs', rnn_outputs) # shape=(100, 200, 64)
    # (100, 200, 64)
    # last = rnn_outputs[:, -1, :]
# Attention layer
    with tf.name_scope('Attention_layer'):
        attention_output, alphas = attention(rnn_outputs, 50, return_alphas=True)
    drop = tf.nn.dropout(attention_output, keep_prob)
    print(drop.shape)# (100, 128)
    
        # tf.summary.histogram('alphas', alphas)
    # 网络initializer的一种方法
    """scale = 1.0 / math.sqrt(hps.num_embedding_size + hps.num_lstm_nodes[-1]) / 3.0
    lstm_init = tf.random_uniform_initializer(-scale, scale)
    # 构建lstm
    with tf.variable_scope('lstm_nn', initializer=lstm_init):
        cells = []
        for i in range(hps.num_lstm_layers):
            # 循环初始化lstm
            cell = tf.contrib.rnn.BasicLSTMCell(
                hps.num_lstm_nodes[i],
                state_is_tuple = True
            )
            # 使用dropout方法
            cell = tf.contrib.rnn.DropoutWrapper(
                cell,
                output_keep_prob = keep_prob
            )
            cells.append(cell)
        # 合并两个cell
        cell = tf.contrib.rnn.MultiRNNCell(cells)
        # 初始化cell内的值
        initial_state = cell.zero_state(batch_size, tf.float32)
        # run_outputs: [batch_size, num_timesteps, lstm_outpus[-1]]
        run_outputs, _ = tf.nn.dynamic_rnn(
            cell, embed_inputs, initial_state=initial_state
        )
        print(run_outputs)
        last = run_outputs[:, -1, :]"""
    fc_init = tf.uniform_unit_scaling_initializer(factor=1.0)
    # lstm连接到全连接层
    with tf.variable_scope('fc', initializer=fc_init):
        fc1 = tf.layers.dense(drop,
                              hps.num_fc_nodes,
                              activation=tf.nn.relu,
                              name='fc1')
        fc1_dropout = tf.layers.dropout(fc1, keep_prob)
        logits = tf.layers.dense(fc1_dropout,
                                 num_classes,
                                 name='fc2')
        
        # W = tf.Variable(tf.truncated_normal([150 * 2, 1], stddev=0.1))
        # b = tf.Variable(tf.constant(0., shape=[1]))
        # y_hat = tf.nn.xw_plus_b(tf.cast(drop, dtype=tf.int32), W, b)
        # y_hat = tf.squeeze(y_hat)
        # tf.summary
    # 计算损失函数
    
    with tf.name_scope('metrics'):
        
        sofmax_loss = tf.nn.sparse_softmax_cross_entropy_with_logits(
            logits=logits, labels= outputs
        )
        loss = tf.reduce_mean(sofmax_loss)
        # optimzer = tf.train.AdamOptimizer(learning_rate=1e-3).minimize(loss)
        
        y_pred = tf.arg_max(tf.nn.softmax(logits=logits),
                            1,
                            output_type= tf.int32)
        correct_pred = tf.equal(outputs, y_pred)
        # accuracy = tf.reduce_mean(tf.cast(tf.equal(tf.round(tf.sigmoid(y_hat)), outputs), tf.float32))
        accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))
    
    # 构建train_op
    
    with tf.name_scope('train_op'):
        tvars = tf.trainable_variables()
        for var in tvars:
            tf.logging.info('variable name: {}'.format(var.name))
        # 限制训练时的梯度大小,使得不会出现梯度爆炸
        grads, _ = tf.clip_by_global_norm(
            tf.gradients(loss, tvars), hps.clip_lstm_grads
        )
        # 梯度应用到变量中去
        optimizer = tf.train.AdamOptimizer(hps.learning_rate)
        train_op = optimizer.apply_gradients(
            zip(grads, tvars), global_step= global_step
        )
    
    # return ((inputs, outputs, keep_prob),
    return ((inputs, outputs, keep_prob, seq_len_ph),
            (loss, accuracy),
            # (optimzer)
            (train_op, global_step)
            )

placeholders, metrics, others = create_model(
    hps, vocab_size, num_classes
)
# inputs, outputs, keep_prod = placeholders
inputs, outputs, keep_prod, seq_len_ph = placeholders
loss, accuracy = metrics
train_op, global_step = others
# optimzer = others
# Out:
# WARNING:tensorflow:From D:\Anaconda\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# embeddings <tf.Variable 'embedding/embedding:0' shape=(85431, 32) dtype=float32_ref>
# embed_inputs Tensor("embedding/embedding_lookup/Identity:0", shape=(100, 200, 32), dtype=float32)
# WARNING:tensorflow:From <ipython-input-6-f2a6f549a83a>:37: GRUCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.GRUCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From <ipython-input-6-f2a6f549a83a>:38: bidirectional_dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.Bidirectional(keras.layers.RNN(cell))`, which is equivalent to this API
# WARNING:tensorflow:From D:\Anaconda\lib\site-packages\tensorflow\python\ops\rnn.py:443: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From D:\Anaconda\lib\site-packages\tensorflow\python\ops\rnn.py:626: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# rnn_outputs (<tf.Tensor 'bidirectional_rnn/fw/fw/transpose_1:0' shape=(100, 200, 64) dtype=float32>, <tf.Tensor 'ReverseSequence:0' shape=(100, 200, 64) dtype=float32>)
# WARNING:tensorflow:From <ipython-input-6-f2a6f549a83a>:46: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# (100, 128)
# WARNING:tensorflow:From <ipython-input-6-f2a6f549a83a>:78: UniformUnitScaling.__init__ (from tensorflow.python.ops.init_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.initializers.variance_scaling instead with distribution=uniform to get equivalent behavior.
# WARNING:tensorflow:From <ipython-input-6-f2a6f549a83a>:84: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# WARNING:tensorflow:From <ipython-input-6-f2a6f549a83a>:85: dropout (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dropout instead.
# WARNING:tensorflow:From <ipython-input-6-f2a6f549a83a>:107: arg_max (from tensorflow.python.ops.gen_math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.math.argmax` instead
# INFO:tensorflow:variable name: embedding/embedding:0
# INFO:tensorflow:variable name: bidirectional_rnn/fw/gru_cell/gates/kernel:0
# INFO:tensorflow:variable name: bidirectional_rnn/fw/gru_cell/gates/bias:0
# INFO:tensorflow:variable name: bidirectional_rnn/fw/gru_cell/candidate/kernel:0
# INFO:tensorflow:variable name: bidirectional_rnn/fw/gru_cell/candidate/bias:0
# INFO:tensorflow:variable name: bidirectional_rnn/bw/gru_cell/gates/kernel:0
# INFO:tensorflow:variable name: bidirectional_rnn/bw/gru_cell/gates/bias:0
# INFO:tensorflow:variable name: bidirectional_rnn/bw/gru_cell/candidate/kernel:0
# INFO:tensorflow:variable name: bidirectional_rnn/bw/gru_cell/candidate/bias:0
# INFO:tensorflow:variable name: Attention_layer/Variable:0
# INFO:tensorflow:variable name: Attention_layer/Variable_1:0
# INFO:tensorflow:variable name: Attention_layer/Variable_2:0
# INFO:tensorflow:variable name: fc/fc1/kernel:0
# INFO:tensorflow:variable name: fc/fc1/bias:0
# INFO:tensorflow:variable name: fc/fc2/kernel:0
# INFO:tensorflow:variable name: fc/fc2/bias:0

# %%
# train:
init_op = tf.global_variables_initializer()
train_keep_prob_value = 0.8
test_keep_prob_value = 1.0

test_steps = 100
num_train_steps = 10000

with tf.Session() as sess:
    sess.run(init_op)
    for i in range(num_train_steps):
        batch_inputs, batch_labels = train_dataset.next_batch(
            hps.batch_size
        )
        
        seq_len = np.array([list(x).index(1)+1 if 1 in x else hps.num_timesteps for x in batch_inputs])
        outputs_val = sess.run([loss, accuracy, train_op, global_step],
        
        # outputs_val = sess.run([loss, accuracy, optimzer],
                               feed_dict = {
                                inputs: batch_inputs,
                                outputs: batch_labels,
                                   keep_prod: train_keep_prob_value,
                                   seq_len_ph: seq_len
                                   
                               })
        loss_val, accuracy_val, _, global_step_val = outputs_val
        # loss_val, accuracy_val, optimzer = outputs_val
        if (i+1) % 20 == 0:
            tf.logging.info("Train Step: {}, loss: {}, accuracy: {}".format(i, loss_val, accuracy_val))

        if (i+1) % 100 == 0:
            all_test_acc_cal = []
            for j in range(test_steps):
                test_inputs, test_labels = test_dataset.next_batch(hps.batch_size)
                seq_len = np.array([list(x).index(1)+1 if 1 in x else hps.num_timesteps for x in test_inputs])
                test_val = sess.run([loss, accuracy, train_op, global_step],
                # test_val = sess.run([loss, accuracy, optimzer],
                                    feed_dict= {
                                        inputs: test_inputs,
                                        outputs: test_labels,
                                        seq_len_ph: seq_len,
                                        keep_prod: test_keep_prob_value,
                                    })
                test_loss_val, test_accuarcy_val, _, test_step_val = test_val
                # test_loss_val, test_accuarcy_val, optimzer = test_val
                all_test_acc_cal.append(test_accuarcy_val)
            test_acc = np.mean(all_test_acc_cal)
            tf.logging.info("Test Step: {}, loss: {}, accuracy: {}".format(i, test_loss_val, test_acc))
# Out:
# INFO:tensorflow:Train Step: 19, loss: 2.459465742111206, accuracy: 0.20999999344348907
# INFO:tensorflow:Train Step: 39, loss: 2.413097620010376, accuracy: 0.15000000596046448
# INFO:tensorflow:Train Step: 59, loss: 2.3422775268554688, accuracy: 0.18000000715255737
# INFO:tensorflow:Train Step: 79, loss: 2.146698236465454, accuracy: 0.23999999463558197
# INFO:tensorflow:Train Step: 99, loss: 2.185227870941162, accuracy: 0.1899999976158142
# INFO:tensorflow:Test Step: 99, loss: 1.7761415243148804, accuracy: 0.3418000042438507
# INFO:tensorflow:Train Step: 119, loss: 1.8352121114730835, accuracy: 0.3799999952316284
# INFO:tensorflow:Train Step: 139, loss: 1.4725143909454346, accuracy: 0.46000000834465027
# INFO:tensorflow:Train Step: 159, loss: 1.5246915817260742, accuracy: 0.47999998927116394
# INFO:tensorflow:Train Step: 179, loss: 1.5380370616912842, accuracy: 0.47999998927116394
# INFO:tensorflow:Train Step: 199, loss: 1.592097282409668, accuracy: 0.49000000953674316
# INFO:tensorflow:Test Step: 199, loss: 1.1719316244125366, accuracy: 0.5658000111579895
# INFO:tensorflow:Train Step: 219, loss: 1.7470370531082153, accuracy: 0.4099999964237213
# INFO:tensorflow:Train Step: 239, loss: 0.9179742336273193, accuracy: 0.7300000190734863
# INFO:tensorflow:Train Step: 259, loss: 1.1221609115600586, accuracy: 0.6800000071525574
# INFO:tensorflow:Train Step: 279, loss: 1.0351358652114868, accuracy: 0.6600000262260437
# INFO:tensorflow:Train Step: 299, loss: 0.9933747053146362, accuracy: 0.7400000095367432
# INFO:tensorflow:Test Step: 299, loss: 0.7794078588485718, accuracy: 0.7013000249862671
# INFO:tensorflow:Train Step: 319, loss: 0.6360703706741333, accuracy: 0.8399999737739563
# INFO:tensorflow:Train Step: 339, loss: 1.0436830520629883, accuracy: 0.699999988079071
# INFO:tensorflow:Train Step: 359, loss: 0.8795033097267151, accuracy: 0.6899999976158142
# INFO:tensorflow:Train Step: 379, loss: 0.7970284223556519, accuracy: 0.7799999713897705
# INFO:tensorflow:Train Step: 399, loss: 0.9392820596694946, accuracy: 0.6600000262260437
# INFO:tensorflow:Test Step: 399, loss: 0.6179948449134827, accuracy: 0.7796000838279724
# INFO:tensorflow:Train Step: 419, loss: 0.8132959008216858, accuracy: 0.75
# INFO:tensorflow:Train Step: 439, loss: 0.7936353087425232, accuracy: 0.75
# INFO:tensorflow:Train Step: 459, loss: 0.8809237480163574, accuracy: 0.7200000286102295
# INFO:tensorflow:Train Step: 479, loss: 0.8240617513656616, accuracy: 0.7699999809265137
# INFO:tensorflow:Train Step: 499, loss: 0.5502591729164124, accuracy: 0.8399999737739563
# INFO:tensorflow:Test Step: 499, loss: 0.38656115531921387, accuracy: 0.8381999731063843
# INFO:tensorflow:Train Step: 519, loss: 0.5849828124046326, accuracy: 0.8399999737739563
# INFO:tensorflow:Train Step: 539, loss: 0.6326756477355957, accuracy: 0.7900000214576721
# INFO:tensorflow:Train Step: 559, loss: 0.5731212496757507, accuracy: 0.8199999928474426
# INFO:tensorflow:Train Step: 579, loss: 0.7710642218589783, accuracy: 0.7799999713897705
# INFO:tensorflow:Train Step: 599, loss: 0.5032289624214172, accuracy: 0.8500000238418579
# INFO:tensorflow:Test Step: 599, loss: 0.2903482913970947, accuracy: 0.8784000277519226
# INFO:tensorflow:Train Step: 619, loss: 0.6264551281929016, accuracy: 0.7900000214576721
# INFO:tensorflow:Train Step: 639, loss: 0.550104558467865, accuracy: 0.8199999928474426
# INFO:tensorflow:Train Step: 659, loss: 0.4291512370109558, accuracy: 0.8399999737739563
# INFO:tensorflow:Train Step: 679, loss: 0.5478501319885254, accuracy: 0.8399999737739563
# INFO:tensorflow:Train Step: 699, loss: 0.4164411425590515, accuracy: 0.8600000143051147
# INFO:tensorflow:Test Step: 699, loss: 0.3633652627468109, accuracy: 0.9107000231742859
# INFO:tensorflow:Train Step: 719, loss: 0.30848923325538635, accuracy: 0.8999999761581421
# INFO:tensorflow:Train Step: 739, loss: 0.5202158689498901, accuracy: 0.8500000238418579
# INFO:tensorflow:Train Step: 759, loss: 0.4186336398124695, accuracy: 0.8500000238418579
# INFO:tensorflow:Train Step: 779, loss: 0.34155791997909546, accuracy: 0.9100000262260437
# INFO:tensorflow:Train Step: 799, loss: 0.3541090786457062, accuracy: 0.8399999737739563
# INFO:tensorflow:Test Step: 799, loss: 0.2604413628578186, accuracy: 0.9318000078201294
# INFO:tensorflow:Train Step: 819, loss: 0.3511453866958618, accuracy: 0.8999999761581421
# INFO:tensorflow:Train Step: 839, loss: 0.3826490640640259, accuracy: 0.8899999856948853
# INFO:tensorflow:Train Step: 859, loss: 0.3954803943634033, accuracy: 0.8700000047683716
# INFO:tensorflow:Train Step: 879, loss: 0.36049529910087585, accuracy: 0.8999999761581421
# INFO:tensorflow:Train Step: 899, loss: 0.3320941925048828, accuracy: 0.8799999952316284
# INFO:tensorflow:Test Step: 899, loss: 0.09023713320493698, accuracy: 0.9484000205993652
# INFO:tensorflow:Train Step: 919, loss: 0.39545294642448425, accuracy: 0.8799999952316284
# INFO:tensorflow:Train Step: 939, loss: 0.365834504365921, accuracy: 0.9300000071525574
# INFO:tensorflow:Train Step: 959, loss: 0.31765204668045044, accuracy: 0.9100000262260437
# INFO:tensorflow:Train Step: 979, loss: 0.3249860405921936, accuracy: 0.9100000262260437
# INFO:tensorflow:Train Step: 999, loss: 0.4244256913661957, accuracy: 0.9100000262260437
# INFO:tensorflow:Test Step: 999, loss: 0.08331554383039474, accuracy: 0.9629001021385193
# INFO:tensorflow:Train Step: 1019, loss: 0.18390659987926483, accuracy: 0.949999988079071
# INFO:tensorflow:Train Step: 1039, loss: 0.35532039403915405, accuracy: 0.8799999952316284
# INFO:tensorflow:Train Step: 1059, loss: 0.26693108677864075, accuracy: 0.9100000262260437
# INFO:tensorflow:Train Step: 1079, loss: 0.27257490158081055, accuracy: 0.9399999976158142
# INFO:tensorflow:Train Step: 1099, loss: 0.20143413543701172, accuracy: 0.9599999785423279
# INFO:tensorflow:Test Step: 1099, loss: 0.10645215213298798, accuracy: 0.9670000672340393
# INFO:tensorflow:Train Step: 1119, loss: 0.3809724748134613, accuracy: 0.8500000238418579
# INFO:tensorflow:Train Step: 1139, loss: 0.2969561517238617, accuracy: 0.9100000262260437
# INFO:tensorflow:Train Step: 1159, loss: 0.225341334939003, accuracy: 0.9200000166893005
# INFO:tensorflow:Train Step: 1179, loss: 0.13030657172203064, accuracy: 0.9700000286102295
# INFO:tensorflow:Train Step: 1199, loss: 0.17830154299736023, accuracy: 0.9300000071525574
# INFO:tensorflow:Test Step: 1199, loss: 0.046365886926651, accuracy: 0.9728000164031982
# INFO:tensorflow:Train Step: 1219, loss: 0.17268574237823486, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 1239, loss: 0.20847484469413757, accuracy: 0.949999988079071
# INFO:tensorflow:Train Step: 1259, loss: 0.2241869568824768, accuracy: 0.9200000166893005
# INFO:tensorflow:Train Step: 1279, loss: 0.24215984344482422, accuracy: 0.9300000071525574
# INFO:tensorflow:Train Step: 1299, loss: 0.2183617353439331, accuracy: 0.9200000166893005
# INFO:tensorflow:Test Step: 1299, loss: 0.05764523148536682, accuracy: 0.9795000553131104
# INFO:tensorflow:Train Step: 1319, loss: 0.18118061125278473, accuracy: 0.9599999785423279
# INFO:tensorflow:Train Step: 1339, loss: 0.2124473601579666, accuracy: 0.9300000071525574
# INFO:tensorflow:Train Step: 1359, loss: 0.26319023966789246, accuracy: 0.9399999976158142
# INFO:tensorflow:Train Step: 1379, loss: 0.28559839725494385, accuracy: 0.9399999976158142
# INFO:tensorflow:Train Step: 1399, loss: 0.1796826869249344, accuracy: 0.9399999976158142
# INFO:tensorflow:Test Step: 1399, loss: 0.0396018847823143, accuracy: 0.9823998808860779
# INFO:tensorflow:Train Step: 1419, loss: 0.28964948654174805, accuracy: 0.9300000071525574
# INFO:tensorflow:Train Step: 1439, loss: 0.15584321320056915, accuracy: 0.9300000071525574
# INFO:tensorflow:Train Step: 1459, loss: 0.09021809697151184, accuracy: 0.9700000286102295
# INFO:tensorflow:Train Step: 1479, loss: 0.18209810554981232, accuracy: 0.949999988079071
# INFO:tensorflow:Train Step: 1499, loss: 0.0941019356250763, accuracy: 0.9700000286102295
# INFO:tensorflow:Test Step: 1499, loss: 0.029600942507386208, accuracy: 0.9837999939918518
# INFO:tensorflow:Train Step: 1519, loss: 0.30021631717681885, accuracy: 0.9100000262260437
# INFO:tensorflow:Train Step: 1539, loss: 0.10951218754053116, accuracy: 0.9800000190734863
# INFO:tensorflow:Train Step: 1559, loss: 0.1898740828037262, accuracy: 0.9700000286102295
# INFO:tensorflow:Train Step: 1579, loss: 0.22440889477729797, accuracy: 0.9300000071525574
# INFO:tensorflow:Train Step: 1599, loss: 0.1376940757036209, accuracy: 0.9599999785423279
# INFO:tensorflow:Test Step: 1599, loss: 0.016861939802765846, accuracy: 0.9850998520851135
# INFO:tensorflow:Train Step: 1619, loss: 0.10380369424819946, accuracy: 0.9599999785423279
# INFO:tensorflow:Train Step: 1639, loss: 0.10837153345346451, accuracy: 0.9599999785423279
# INFO:tensorflow:Train Step: 1659, loss: 0.10933861136436462, accuracy: 0.9700000286102295
# INFO:tensorflow:Train Step: 1679, loss: 0.16835293173789978, accuracy: 0.9700000286102295
# INFO:tensorflow:Train Step: 1699, loss: 0.1497294306755066, accuracy: 0.949999988079071
# INFO:tensorflow:Test Step: 1699, loss: 0.03690079599618912, accuracy: 0.9861999750137329
# INFO:tensorflow:Train Step: 1719, loss: 0.1333087533712387, accuracy: 0.9700000286102295
# INFO:tensorflow:Train Step: 1739, loss: 0.10354907065629959, accuracy: 0.9599999785423279
# INFO:tensorflow:Train Step: 1759, loss: 0.07006194442510605, accuracy: 0.9800000190734863
# INFO:tensorflow:Train Step: 1779, loss: 0.2040119767189026, accuracy: 0.9200000166893005
# INFO:tensorflow:Train Step: 1799, loss: 0.059794288128614426, accuracy: 0.9700000286102295
# INFO:tensorflow:Test Step: 1799, loss: 0.037723466753959656, accuracy: 0.9875999689102173
# INFO:tensorflow:Train Step: 1819, loss: 0.21673740446567535, accuracy: 0.949999988079071
# INFO:tensorflow:Train Step: 1839, loss: 0.10524559766054153, accuracy: 0.9700000286102295
# INFO:tensorflow:Train Step: 1859, loss: 0.3519747257232666, accuracy: 0.9399999976158142
# INFO:tensorflow:Train Step: 1879, loss: 0.2313547134399414, accuracy: 0.9200000166893005
# INFO:tensorflow:Train Step: 1899, loss: 0.15168550610542297, accuracy: 0.9599999785423279
# INFO:tensorflow:Test Step: 1899, loss: 0.029173076152801514, accuracy: 0.9899000525474548
# INFO:tensorflow:Train Step: 1919, loss: 0.25446847081184387, accuracy: 0.9399999976158142
# INFO:tensorflow:Train Step: 1939, loss: 0.04340357333421707, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 1959, loss: 0.09761429578065872, accuracy: 0.9700000286102295
# INFO:tensorflow:Train Step: 1979, loss: 0.04122752696275711, accuracy: 0.9800000190734863
# INFO:tensorflow:Train Step: 1999, loss: 0.12729673087596893, accuracy: 0.9599999785423279
# INFO:tensorflow:Test Step: 1999, loss: 0.0334286205470562, accuracy: 0.9905999898910522
# INFO:tensorflow:Train Step: 2019, loss: 0.04568786919116974, accuracy: 0.9800000190734863
# INFO:tensorflow:Train Step: 2039, loss: 0.07195829600095749, accuracy: 0.9599999785423279
# INFO:tensorflow:Train Step: 2059, loss: 0.047674570232629776, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 2079, loss: 0.25450047850608826, accuracy: 0.949999988079071
# INFO:tensorflow:Train Step: 2099, loss: 0.11238507181406021, accuracy: 0.9700000286102295
# INFO:tensorflow:Test Step: 2099, loss: 0.013261743821203709, accuracy: 0.9896000027656555
# INFO:tensorflow:Train Step: 2119, loss: 0.052821263670921326, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 2139, loss: 0.10933829098939896, accuracy: 0.9599999785423279
# INFO:tensorflow:Train Step: 2159, loss: 0.07383422553539276, accuracy: 0.9800000190734863
# INFO:tensorflow:Train Step: 2179, loss: 0.040777601301670074, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 2199, loss: 0.04196596518158913, accuracy: 0.9800000190734863
# INFO:tensorflow:Test Step: 2199, loss: 0.006427475716918707, accuracy: 0.9901000261306763
# INFO:tensorflow:Train Step: 2219, loss: 0.1341690570116043, accuracy: 0.9599999785423279
# INFO:tensorflow:Train Step: 2239, loss: 0.03617680072784424, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 2259, loss: 0.0878201276063919, accuracy: 0.9599999785423279
# INFO:tensorflow:Train Step: 2279, loss: 0.04393090307712555, accuracy: 0.9800000190734863
# INFO:tensorflow:Train Step: 2299, loss: 0.1374601423740387, accuracy: 0.9700000286102295
# INFO:tensorflow:Test Step: 2299, loss: 0.011293623596429825, accuracy: 0.9919000267982483
# INFO:tensorflow:Train Step: 2319, loss: 0.03699556738138199, accuracy: 1.0
# INFO:tensorflow:Train Step: 2339, loss: 0.06857766211032867, accuracy: 0.9700000286102295
# INFO:tensorflow:Train Step: 2359, loss: 0.09854698181152344, accuracy: 0.9599999785423279
# INFO:tensorflow:Train Step: 2379, loss: 0.019378921017050743, accuracy: 1.0
# INFO:tensorflow:Train Step: 2399, loss: 0.023902134969830513, accuracy: 0.9900000095367432
# INFO:tensorflow:Test Step: 2399, loss: 0.01518550980836153, accuracy: 0.9899999499320984
# INFO:tensorflow:Train Step: 2419, loss: 0.02758738026022911, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 2439, loss: 0.1037275567650795, accuracy: 0.9700000286102295
# INFO:tensorflow:Train Step: 2459, loss: 0.09927019476890564, accuracy: 0.9700000286102295
# INFO:tensorflow:Train Step: 2479, loss: 0.12594793736934662, accuracy: 0.9599999785423279
# INFO:tensorflow:Train Step: 2499, loss: 0.0950596034526825, accuracy: 0.9700000286102295
# INFO:tensorflow:Test Step: 2499, loss: 0.016875745728611946, accuracy: 0.9921999573707581
# INFO:tensorflow:Train Step: 2519, loss: 0.08562449365854263, accuracy: 0.9700000286102295
# INFO:tensorflow:Train Step: 2539, loss: 0.024048201739788055, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 2559, loss: 0.037246137857437134, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 2579, loss: 0.0773710310459137, accuracy: 0.9800000190734863
# INFO:tensorflow:Train Step: 2599, loss: 0.05711532011628151, accuracy: 0.9800000190734863
# INFO:tensorflow:Test Step: 2599, loss: 0.004344998858869076, accuracy: 0.9935998320579529
# INFO:tensorflow:Train Step: 2619, loss: 0.05115450546145439, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 2639, loss: 0.054556798189878464, accuracy: 0.9700000286102295
# INFO:tensorflow:Train Step: 2659, loss: 0.023658208549022675, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 2679, loss: 0.05574417486786842, accuracy: 0.9599999785423279
# INFO:tensorflow:Train Step: 2699, loss: 0.031247420236468315, accuracy: 0.9900000095367432
# INFO:tensorflow:Test Step: 2699, loss: 0.007916947826743126, accuracy: 0.9927999973297119
# INFO:tensorflow:Train Step: 2719, loss: 0.004211174324154854, accuracy: 1.0
# INFO:tensorflow:Train Step: 2739, loss: 0.021141327917575836, accuracy: 1.0
# INFO:tensorflow:Train Step: 2759, loss: 0.020542649552226067, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 2779, loss: 0.09256844222545624, accuracy: 0.949999988079071
# INFO:tensorflow:Train Step: 2799, loss: 0.03571183234453201, accuracy: 1.0
# INFO:tensorflow:Test Step: 2799, loss: 0.0397757887840271, accuracy: 0.9936000108718872
# INFO:tensorflow:Train Step: 2819, loss: 0.005545169115066528, accuracy: 1.0
# INFO:tensorflow:Train Step: 2839, loss: 0.008562121540307999, accuracy: 1.0
# INFO:tensorflow:Train Step: 2859, loss: 0.06720390170812607, accuracy: 0.9700000286102295
# INFO:tensorflow:Train Step: 2879, loss: 0.07549475133419037, accuracy: 0.9800000190734863
# INFO:tensorflow:Train Step: 2899, loss: 0.045929983258247375, accuracy: 0.9800000190734863
# INFO:tensorflow:Test Step: 2899, loss: 0.004430366214364767, accuracy: 0.9930999875068665
# INFO:tensorflow:Train Step: 2919, loss: 0.004637213423848152, accuracy: 1.0
# INFO:tensorflow:Train Step: 2939, loss: 0.055589985102415085, accuracy: 0.9800000190734863
# INFO:tensorflow:Train Step: 2959, loss: 0.039217740297317505, accuracy: 0.9800000190734863
# INFO:tensorflow:Train Step: 2979, loss: 0.01778472401201725, accuracy: 1.0
# INFO:tensorflow:Train Step: 2999, loss: 0.11444193869829178, accuracy: 0.9800000190734863
# INFO:tensorflow:Test Step: 2999, loss: 0.06946198642253876, accuracy: 0.9928999543190002
# INFO:tensorflow:Train Step: 3019, loss: 0.026739634573459625, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 3039, loss: 0.04380209743976593, accuracy: 0.9800000190734863
# INFO:tensorflow:Train Step: 3059, loss: 0.024853555485606194, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 3079, loss: 0.026565995067358017, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 3099, loss: 0.020299402996897697, accuracy: 0.9900000095367432
# INFO:tensorflow:Test Step: 3099, loss: 0.00876302644610405, accuracy: 0.9929999709129333
# INFO:tensorflow:Train Step: 3119, loss: 0.05989973992109299, accuracy: 0.9700000286102295
# INFO:tensorflow:Train Step: 3139, loss: 0.08903484046459198, accuracy: 0.9800000190734863
# INFO:tensorflow:Train Step: 3159, loss: 0.004611709155142307, accuracy: 1.0
# INFO:tensorflow:Train Step: 3179, loss: 0.005084382835775614, accuracy: 1.0
# INFO:tensorflow:Train Step: 3199, loss: 0.03383168950676918, accuracy: 0.9900000095367432
# INFO:tensorflow:Test Step: 3199, loss: 0.0018966469215229154, accuracy: 0.9943000078201294
# INFO:tensorflow:Train Step: 3219, loss: 0.020994918420910835, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 3239, loss: 0.010107462294399738, accuracy: 1.0
# INFO:tensorflow:Train Step: 3259, loss: 0.024277502670884132, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 3279, loss: 0.06198447570204735, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 3299, loss: 0.06914463639259338, accuracy: 0.9900000095367432
# INFO:tensorflow:Test Step: 3299, loss: 0.0038271325174719095, accuracy: 0.9939000010490417
# INFO:tensorflow:Train Step: 3319, loss: 0.011803911998867989, accuracy: 1.0
# INFO:tensorflow:Train Step: 3339, loss: 0.039316512644290924, accuracy: 0.9800000190734863
# INFO:tensorflow:Train Step: 3359, loss: 0.00996001623570919, accuracy: 1.0
# INFO:tensorflow:Train Step: 3379, loss: 0.014755054377019405, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 3399, loss: 0.04615788906812668, accuracy: 0.9800000190734863
# INFO:tensorflow:Test Step: 3399, loss: 0.009670539759099483, accuracy: 0.9950999617576599
# INFO:tensorflow:Train Step: 3419, loss: 0.010467066429555416, accuracy: 1.0
# INFO:tensorflow:Train Step: 3439, loss: 0.001633657026104629, accuracy: 1.0
# INFO:tensorflow:Train Step: 3459, loss: 0.0801410898566246, accuracy: 0.9800000190734863
# INFO:tensorflow:Train Step: 3479, loss: 0.06785567104816437, accuracy: 0.9800000190734863
# INFO:tensorflow:Train Step: 3499, loss: 0.017198296263813972, accuracy: 1.0
# INFO:tensorflow:Test Step: 3499, loss: 0.018849888816475868, accuracy: 0.9942999482154846
# INFO:tensorflow:Train Step: 3519, loss: 0.0713438093662262, accuracy: 0.9800000190734863
# INFO:tensorflow:Train Step: 3539, loss: 0.038396671414375305, accuracy: 0.9800000190734863
# INFO:tensorflow:Train Step: 3559, loss: 0.024915695190429688, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 3579, loss: 0.02569015510380268, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 3599, loss: 0.04871845245361328, accuracy: 0.9800000190734863
# INFO:tensorflow:Test Step: 3599, loss: 0.009131536819040775, accuracy: 0.9944999814033508
# INFO:tensorflow:Train Step: 3619, loss: 0.00645767617970705, accuracy: 1.0
# INFO:tensorflow:Train Step: 3639, loss: 0.04765157774090767, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 3659, loss: 0.045565415173769, accuracy: 0.9800000190734863
# INFO:tensorflow:Train Step: 3679, loss: 0.0066427080892026424, accuracy: 1.0
# INFO:tensorflow:Train Step: 3699, loss: 0.023730838671326637, accuracy: 0.9900000095367432
# INFO:tensorflow:Test Step: 3699, loss: 0.04100310429930687, accuracy: 0.9941999912261963
# INFO:tensorflow:Train Step: 3719, loss: 0.006194553803652525, accuracy: 1.0
# INFO:tensorflow:Train Step: 3739, loss: 0.030148418620228767, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 3759, loss: 0.05427545681595802, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 3779, loss: 0.03512769192457199, accuracy: 0.9800000190734863
# INFO:tensorflow:Train Step: 3799, loss: 0.006772438995540142, accuracy: 1.0
# INFO:tensorflow:Test Step: 3799, loss: 0.002265874994918704, accuracy: 0.9950999617576599
# INFO:tensorflow:Train Step: 3819, loss: 0.006834783591330051, accuracy: 1.0
# INFO:tensorflow:Train Step: 3839, loss: 0.03805717080831528, accuracy: 0.9800000190734863
# INFO:tensorflow:Train Step: 3859, loss: 0.01145239919424057, accuracy: 1.0
# INFO:tensorflow:Train Step: 3879, loss: 0.03192087262868881, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 3899, loss: 0.035972949117422104, accuracy: 0.9800000190734863
# INFO:tensorflow:Test Step: 3899, loss: 0.03519411385059357, accuracy: 0.9949999451637268
# INFO:tensorflow:Train Step: 3919, loss: 0.029916448518633842, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 3939, loss: 0.04058665409684181, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 3959, loss: 0.03351325914263725, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 3979, loss: 0.0455864854156971, accuracy: 0.9800000190734863
# INFO:tensorflow:Train Step: 3999, loss: 0.03000492788851261, accuracy: 0.9800000190734863
# INFO:tensorflow:Test Step: 3999, loss: 0.038096968084573746, accuracy: 0.9951000213623047
# INFO:tensorflow:Train Step: 4019, loss: 0.003463354194536805, accuracy: 1.0
# INFO:tensorflow:Train Step: 4039, loss: 0.026645632460713387, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 4059, loss: 0.019942471757531166, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 4079, loss: 0.018163761124014854, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 4099, loss: 0.0029054360929876566, accuracy: 1.0
# INFO:tensorflow:Test Step: 4099, loss: 0.004078440368175507, accuracy: 0.9942999482154846
# INFO:tensorflow:Train Step: 4119, loss: 0.02702689729630947, accuracy: 0.9800000190734863
# INFO:tensorflow:Train Step: 4139, loss: 0.00856921449303627, accuracy: 1.0
# INFO:tensorflow:Train Step: 4159, loss: 0.042141400277614594, accuracy: 0.9800000190734863
# INFO:tensorflow:Train Step: 4179, loss: 0.028625428676605225, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 4199, loss: 0.06749361753463745, accuracy: 0.9800000190734863
# INFO:tensorflow:Test Step: 4199, loss: 0.0008354895398952067, accuracy: 0.9950999617576599
# INFO:tensorflow:Train Step: 4219, loss: 0.10263045132160187, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 4239, loss: 0.03282339125871658, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 4259, loss: 0.02682676538825035, accuracy: 0.9800000190734863
# INFO:tensorflow:Train Step: 4279, loss: 0.009917642921209335, accuracy: 1.0
# INFO:tensorflow:Train Step: 4299, loss: 0.03495655581355095, accuracy: 0.9900000095367432
# INFO:tensorflow:Test Step: 4299, loss: 0.0010981662198901176, accuracy: 0.9955999851226807
# INFO:tensorflow:Train Step: 4319, loss: 0.06743123382329941, accuracy: 0.9800000190734863
# INFO:tensorflow:Train Step: 4339, loss: 0.003690923098474741, accuracy: 1.0
# INFO:tensorflow:Train Step: 4359, loss: 0.05229336395859718, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 4379, loss: 0.038245294243097305, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 4399, loss: 0.0381176732480526, accuracy: 0.9900000095367432
# INFO:tensorflow:Test Step: 4399, loss: 0.0219096876680851, accuracy: 0.995499849319458
# INFO:tensorflow:Train Step: 4419, loss: 0.030260631814599037, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 4439, loss: 0.0016865869984030724, accuracy: 1.0
# INFO:tensorflow:Train Step: 4459, loss: 0.09169478714466095, accuracy: 0.9700000286102295
# INFO:tensorflow:Train Step: 4479, loss: 0.13725318014621735, accuracy: 0.9599999785423279
# INFO:tensorflow:Train Step: 4499, loss: 0.04560006782412529, accuracy: 0.9800000190734863
# INFO:tensorflow:Test Step: 4499, loss: 0.0072008101269602776, accuracy: 0.9956000447273254
# INFO:tensorflow:Train Step: 4519, loss: 0.01581648550927639, accuracy: 1.0
# INFO:tensorflow:Train Step: 4539, loss: 0.011576395481824875, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 4559, loss: 0.04346157982945442, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 4579, loss: 0.020724261179566383, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 4599, loss: 0.03196755796670914, accuracy: 0.9900000095367432
# INFO:tensorflow:Test Step: 4599, loss: 0.028583994135260582, accuracy: 0.9955999255180359
# INFO:tensorflow:Train Step: 4619, loss: 0.09556561708450317, accuracy: 0.9800000190734863
# INFO:tensorflow:Train Step: 4639, loss: 0.009291081689298153, accuracy: 1.0
# INFO:tensorflow:Train Step: 4659, loss: 0.002511723432689905, accuracy: 1.0
# INFO:tensorflow:Train Step: 4679, loss: 0.036631397902965546, accuracy: 0.9800000190734863
# INFO:tensorflow:Train Step: 4699, loss: 0.06961775571107864, accuracy: 0.9800000190734863
# INFO:tensorflow:Test Step: 4699, loss: 0.005619813222438097, accuracy: 0.9945999979972839
# INFO:tensorflow:Train Step: 4719, loss: 0.039877377450466156, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 4739, loss: 0.036416228860616684, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 4759, loss: 0.0016512662405148149, accuracy: 1.0
# INFO:tensorflow:Train Step: 4779, loss: 0.12169148772954941, accuracy: 0.9800000190734863
# INFO:tensorflow:Train Step: 4799, loss: 0.022118384018540382, accuracy: 0.9900000095367432
# INFO:tensorflow:Test Step: 4799, loss: 0.01872074417769909, accuracy: 0.9957998394966125
# INFO:tensorflow:Train Step: 4819, loss: 0.004667317494750023, accuracy: 1.0
# INFO:tensorflow:Train Step: 4839, loss: 0.011690802872180939, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 4859, loss: 0.06570864468812943, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 4879, loss: 0.011533580720424652, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 4899, loss: 0.056516699492931366, accuracy: 0.9900000095367432
# INFO:tensorflow:Test Step: 4899, loss: 0.0006439653807319701, accuracy: 0.9952000379562378
# INFO:tensorflow:Train Step: 4919, loss: 0.008583173155784607, accuracy: 1.0
# INFO:tensorflow:Train Step: 4939, loss: 0.004753710702061653, accuracy: 1.0
# INFO:tensorflow:Train Step: 4959, loss: 0.0037950011901557446, accuracy: 1.0
# INFO:tensorflow:Train Step: 4979, loss: 0.03534654155373573, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 4999, loss: 0.009583262726664543, accuracy: 1.0
# INFO:tensorflow:Test Step: 4999, loss: 0.008432069793343544, accuracy: 0.9948999285697937
# INFO:tensorflow:Train Step: 5019, loss: 0.0020098427776247263, accuracy: 1.0
# INFO:tensorflow:Train Step: 5039, loss: 0.019275613129138947, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 5059, loss: 0.014443699270486832, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 5079, loss: 0.040869876742362976, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 5099, loss: 0.004008771385997534, accuracy: 1.0
# INFO:tensorflow:Test Step: 5099, loss: 0.0062193660996854305, accuracy: 0.9957000017166138
# INFO:tensorflow:Train Step: 5119, loss: 0.003384050214663148, accuracy: 1.0
# INFO:tensorflow:Train Step: 5139, loss: 0.011949505656957626, accuracy: 1.0
# INFO:tensorflow:Train Step: 5159, loss: 0.09780222922563553, accuracy: 0.9700000286102295
# INFO:tensorflow:Train Step: 5179, loss: 0.0012823722790926695, accuracy: 1.0
# INFO:tensorflow:Train Step: 5199, loss: 0.0402148999273777, accuracy: 0.9900000095367432
# INFO:tensorflow:Test Step: 5199, loss: 0.04360707849264145, accuracy: 0.9959999918937683
# INFO:tensorflow:Train Step: 5219, loss: 0.030360303819179535, accuracy: 0.9800000190734863
# INFO:tensorflow:Train Step: 5239, loss: 0.09519795328378677, accuracy: 0.9700000286102295
# INFO:tensorflow:Train Step: 5259, loss: 0.013493521139025688, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 5279, loss: 0.02308821864426136, accuracy: 0.9800000190734863
# INFO:tensorflow:Train Step: 5299, loss: 0.037567365914583206, accuracy: 0.9900000095367432
# INFO:tensorflow:Test Step: 5299, loss: 0.0027882715221494436, accuracy: 0.9952999949455261
# INFO:tensorflow:Train Step: 5319, loss: 0.0015718120848760009, accuracy: 1.0
# INFO:tensorflow:Train Step: 5339, loss: 0.19763755798339844, accuracy: 0.9399999976158142
# INFO:tensorflow:Train Step: 5359, loss: 0.06985827535390854, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 5379, loss: 0.07131626456975937, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 5399, loss: 0.0019158885115757585, accuracy: 1.0
# INFO:tensorflow:Test Step: 5399, loss: 0.006352356169372797, accuracy: 0.9947998523712158
# INFO:tensorflow:Train Step: 5419, loss: 0.04573342949151993, accuracy: 0.9800000190734863
# INFO:tensorflow:Train Step: 5439, loss: 0.07958181202411652, accuracy: 0.9800000190734863
# INFO:tensorflow:Train Step: 5459, loss: 0.020217884331941605, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 5479, loss: 0.030471667647361755, accuracy: 0.9800000190734863
# INFO:tensorflow:Train Step: 5499, loss: 0.006772756576538086, accuracy: 1.0
# INFO:tensorflow:Test Step: 5499, loss: 0.0051988535560667515, accuracy: 0.9964999556541443
# INFO:tensorflow:Train Step: 5519, loss: 0.011367176659405231, accuracy: 1.0
# INFO:tensorflow:Train Step: 5539, loss: 0.06358323991298676, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 5559, loss: 0.010567128658294678, accuracy: 1.0
# INFO:tensorflow:Train Step: 5579, loss: 0.05061037838459015, accuracy: 0.9800000190734863
# INFO:tensorflow:Train Step: 5599, loss: 0.0038283211179077625, accuracy: 1.0
# INFO:tensorflow:Test Step: 5599, loss: 0.0008793857414275408, accuracy: 0.9963999390602112
# INFO:tensorflow:Train Step: 5619, loss: 0.05430168658494949, accuracy: 0.9800000190734863
# INFO:tensorflow:Train Step: 5639, loss: 0.02561814710497856, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 5659, loss: 0.003567673033103347, accuracy: 1.0
# INFO:tensorflow:Train Step: 5679, loss: 0.0036674959119409323, accuracy: 1.0
# INFO:tensorflow:Train Step: 5699, loss: 0.03198309987783432, accuracy: 0.9900000095367432
# INFO:tensorflow:Test Step: 5699, loss: 0.004054832737892866, accuracy: 0.9962999820709229
# INFO:tensorflow:Train Step: 5719, loss: 0.004718571435660124, accuracy: 1.0
# INFO:tensorflow:Train Step: 5739, loss: 0.03900345414876938, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 5759, loss: 0.023276619613170624, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 5779, loss: 0.03941095247864723, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 5799, loss: 0.0023187545593827963, accuracy: 1.0
# INFO:tensorflow:Test Step: 5799, loss: 0.004211715888231993, accuracy: 0.996399998664856
# INFO:tensorflow:Train Step: 5819, loss: 0.003056442830711603, accuracy: 1.0
# INFO:tensorflow:Train Step: 5839, loss: 0.02004907839000225, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 5859, loss: 0.06702354550361633, accuracy: 0.9599999785423279
# INFO:tensorflow:Train Step: 5879, loss: 0.00202179211191833, accuracy: 1.0
# INFO:tensorflow:Train Step: 5899, loss: 0.003733716206625104, accuracy: 1.0
# INFO:tensorflow:Test Step: 5899, loss: 0.004899282939732075, accuracy: 0.9955999851226807
# INFO:tensorflow:Train Step: 5919, loss: 0.002985408529639244, accuracy: 1.0
# INFO:tensorflow:Train Step: 5939, loss: 0.001200635451823473, accuracy: 1.0
# INFO:tensorflow:Train Step: 5959, loss: 0.05980239063501358, accuracy: 0.9800000190734863
# INFO:tensorflow:Train Step: 5979, loss: 0.0040266308933496475, accuracy: 1.0
# INFO:tensorflow:Train Step: 5999, loss: 0.005077198147773743, accuracy: 1.0
# INFO:tensorflow:Test Step: 5999, loss: 0.0014803576050326228, accuracy: 0.995699942111969
# INFO:tensorflow:Train Step: 6019, loss: 0.03189387917518616, accuracy: 0.9800000190734863
# INFO:tensorflow:Train Step: 6039, loss: 0.013341192156076431, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 6059, loss: 0.008693874813616276, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 6079, loss: 0.007301639299839735, accuracy: 1.0
# INFO:tensorflow:Train Step: 6099, loss: 0.010096555575728416, accuracy: 1.0
# INFO:tensorflow:Test Step: 6099, loss: 0.0008422961691394448, accuracy: 0.9955999255180359
# INFO:tensorflow:Train Step: 6119, loss: 0.006084009539335966, accuracy: 1.0
# INFO:tensorflow:Train Step: 6139, loss: 0.0014028495643287897, accuracy: 1.0
# INFO:tensorflow:Train Step: 6159, loss: 0.013189785182476044, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 6179, loss: 0.009676055051386356, accuracy: 1.0
# INFO:tensorflow:Train Step: 6199, loss: 0.004155234899371862, accuracy: 1.0
# INFO:tensorflow:Test Step: 6199, loss: 0.00040824702591635287, accuracy: 0.9962999224662781
# INFO:tensorflow:Train Step: 6219, loss: 0.0013184344861656427, accuracy: 1.0
# INFO:tensorflow:Train Step: 6239, loss: 0.006900031119585037, accuracy: 1.0
# INFO:tensorflow:Train Step: 6259, loss: 0.031228531152009964, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 6279, loss: 0.0419515036046505, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 6299, loss: 0.003325261175632477, accuracy: 1.0
# INFO:tensorflow:Test Step: 6299, loss: 0.0037349204067140818, accuracy: 0.9961999654769897
# INFO:tensorflow:Train Step: 6319, loss: 0.0034366061445325613, accuracy: 1.0
# INFO:tensorflow:Train Step: 6339, loss: 0.025846848264336586, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 6359, loss: 0.0019812972750514746, accuracy: 1.0
# INFO:tensorflow:Train Step: 6379, loss: 0.021001407876610756, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 6399, loss: 0.03718152269721031, accuracy: 0.9900000095367432
# INFO:tensorflow:Test Step: 6399, loss: 0.0001262515434063971, accuracy: 0.9966999888420105
# INFO:tensorflow:Train Step: 6419, loss: 0.0009703654795885086, accuracy: 1.0
# INFO:tensorflow:Train Step: 6439, loss: 0.0002085333690047264, accuracy: 1.0
# INFO:tensorflow:Train Step: 6459, loss: 0.0006851139478385448, accuracy: 1.0
# INFO:tensorflow:Train Step: 6479, loss: 0.0019928086549043655, accuracy: 1.0
# INFO:tensorflow:Train Step: 6499, loss: 0.015264101326465607, accuracy: 0.9900000095367432
# INFO:tensorflow:Test Step: 6499, loss: 0.001800202182494104, accuracy: 0.9966999888420105
# INFO:tensorflow:Train Step: 6519, loss: 0.001177044934593141, accuracy: 1.0
# INFO:tensorflow:Train Step: 6539, loss: 0.011358445510268211, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 6559, loss: 0.03818347677588463, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 6579, loss: 0.02081000991165638, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 6599, loss: 0.044776156544685364, accuracy: 0.9900000095367432
# INFO:tensorflow:Test Step: 6599, loss: 0.04566337540745735, accuracy: 0.9958000183105469
# INFO:tensorflow:Train Step: 6619, loss: 0.03781525790691376, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 6639, loss: 0.002779014641419053, accuracy: 1.0
# INFO:tensorflow:Train Step: 6659, loss: 0.0012780576944351196, accuracy: 1.0
# INFO:tensorflow:Train Step: 6679, loss: 0.0017991913482546806, accuracy: 1.0
# INFO:tensorflow:Train Step: 6699, loss: 0.004445042926818132, accuracy: 1.0
# INFO:tensorflow:Test Step: 6699, loss: 0.0008958485559560359, accuracy: 0.9952999949455261
# INFO:tensorflow:Train Step: 6719, loss: 0.033372536301612854, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 6739, loss: 0.01725136488676071, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 6759, loss: 0.005648706573992968, accuracy: 1.0
# INFO:tensorflow:Train Step: 6779, loss: 0.000927430170122534, accuracy: 1.0
# INFO:tensorflow:Train Step: 6799, loss: 0.009031805209815502, accuracy: 1.0
# INFO:tensorflow:Test Step: 6799, loss: 0.00014161471335683018, accuracy: 0.9960999488830566
# INFO:tensorflow:Train Step: 6819, loss: 0.009276156313717365, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 6839, loss: 0.010443865321576595, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 6859, loss: 0.005152483005076647, accuracy: 1.0
# INFO:tensorflow:Train Step: 6879, loss: 0.010586869902908802, accuracy: 1.0
# INFO:tensorflow:Train Step: 6899, loss: 0.024563513696193695, accuracy: 0.9900000095367432
# INFO:tensorflow:Test Step: 6899, loss: 0.0005368755664676428, accuracy: 0.9966999888420105
# INFO:tensorflow:Train Step: 6919, loss: 0.0028086877427995205, accuracy: 1.0
# INFO:tensorflow:Train Step: 6939, loss: 0.0013403136981651187, accuracy: 1.0
# INFO:tensorflow:Train Step: 6959, loss: 0.021557314321398735, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 6979, loss: 0.013788837939500809, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 6999, loss: 0.04129382595419884, accuracy: 0.9900000095367432
# INFO:tensorflow:Test Step: 6999, loss: 0.03851601108908653, accuracy: 0.9961000084877014
# INFO:tensorflow:Train Step: 7019, loss: 0.026147672906517982, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 7039, loss: 0.008517266251146793, accuracy: 1.0
# INFO:tensorflow:Train Step: 7059, loss: 0.011277684941887856, accuracy: 1.0
# INFO:tensorflow:Train Step: 7079, loss: 0.0032586553134024143, accuracy: 1.0
# INFO:tensorflow:Train Step: 7099, loss: 0.0017299088649451733, accuracy: 1.0
# INFO:tensorflow:Test Step: 7099, loss: 0.0014775677118450403, accuracy: 0.9965000152587891
# INFO:tensorflow:Train Step: 7119, loss: 0.0026997250970453024, accuracy: 1.0
# INFO:tensorflow:Train Step: 7139, loss: 0.0008533685468137264, accuracy: 1.0
# INFO:tensorflow:Train Step: 7159, loss: 0.0010049082338809967, accuracy: 1.0
# INFO:tensorflow:Train Step: 7179, loss: 0.0125380614772439, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 7199, loss: 0.00028583622770383954, accuracy: 1.0
# INFO:tensorflow:Test Step: 7199, loss: 0.009511997923254967, accuracy: 0.9966999292373657
# INFO:tensorflow:Train Step: 7219, loss: 0.037659283727407455, accuracy: 0.9800000190734863
# INFO:tensorflow:Train Step: 7239, loss: 0.03397025540471077, accuracy: 0.9800000190734863
# INFO:tensorflow:Train Step: 7259, loss: 0.0481974259018898, accuracy: 0.9800000190734863
# INFO:tensorflow:Train Step: 7279, loss: 0.0015873584197834134, accuracy: 1.0
# INFO:tensorflow:Train Step: 7299, loss: 0.001161486841738224, accuracy: 1.0
# INFO:tensorflow:Test Step: 7299, loss: 0.013011455535888672, accuracy: 0.9961000084877014
# INFO:tensorflow:Train Step: 7319, loss: 0.004484866745769978, accuracy: 1.0
# INFO:tensorflow:Train Step: 7339, loss: 0.010329273529350758, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 7359, loss: 0.003135209670290351, accuracy: 1.0
# INFO:tensorflow:Train Step: 7379, loss: 0.0002630190283525735, accuracy: 1.0
# INFO:tensorflow:Train Step: 7399, loss: 0.0011958952527493238, accuracy: 1.0
# INFO:tensorflow:Test Step: 7399, loss: 0.0028940713964402676, accuracy: 0.9958999156951904
# INFO:tensorflow:Train Step: 7419, loss: 0.002327572787180543, accuracy: 1.0
# INFO:tensorflow:Train Step: 7439, loss: 0.013980057090520859, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 7459, loss: 0.018983574584126472, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 7479, loss: 0.005967100150883198, accuracy: 1.0
# INFO:tensorflow:Train Step: 7499, loss: 0.0038116720970720053, accuracy: 1.0
# INFO:tensorflow:Test Step: 7499, loss: 0.0007956901099532843, accuracy: 0.9959999918937683
# INFO:tensorflow:Train Step: 7519, loss: 0.0029245996847748756, accuracy: 1.0
# INFO:tensorflow:Train Step: 7539, loss: 0.01724194549024105, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 7559, loss: 0.002573445439338684, accuracy: 1.0
# INFO:tensorflow:Train Step: 7579, loss: 0.022585554048419, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 7599, loss: 0.0003771478368435055, accuracy: 1.0
# INFO:tensorflow:Test Step: 7599, loss: 0.0007146017742343247, accuracy: 0.9965999722480774
# INFO:tensorflow:Train Step: 7619, loss: 0.0004650591581594199, accuracy: 1.0
# INFO:tensorflow:Train Step: 7639, loss: 0.010728464461863041, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 7659, loss: 0.056269530206918716, accuracy: 0.9800000190734863
# INFO:tensorflow:Train Step: 7679, loss: 0.025304941460490227, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 7699, loss: 0.012736409902572632, accuracy: 1.0
# INFO:tensorflow:Test Step: 7699, loss: 0.00040410590008832514, accuracy: 0.9965999722480774
# INFO:tensorflow:Train Step: 7719, loss: 0.004668573848903179, accuracy: 1.0
# INFO:tensorflow:Train Step: 7739, loss: 0.00386031623929739, accuracy: 1.0
# INFO:tensorflow:Train Step: 7759, loss: 0.01741337589919567, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 7779, loss: 0.04041086137294769, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 7799, loss: 0.026899756863713264, accuracy: 0.9800000190734863
# INFO:tensorflow:Test Step: 7799, loss: 0.0030588083900511265, accuracy: 0.9966999292373657
# INFO:tensorflow:Train Step: 7819, loss: 0.04426960647106171, accuracy: 0.9800000190734863
# INFO:tensorflow:Train Step: 7839, loss: 0.0026437477208673954, accuracy: 1.0
# INFO:tensorflow:Train Step: 7859, loss: 0.001242114114575088, accuracy: 1.0
# INFO:tensorflow:Train Step: 7879, loss: 0.0253908708691597, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 7899, loss: 0.002047999296337366, accuracy: 1.0
# INFO:tensorflow:Test Step: 7899, loss: 0.0012563514756038785, accuracy: 0.9966999292373657
# INFO:tensorflow:Train Step: 7919, loss: 0.0003941631002817303, accuracy: 1.0
# INFO:tensorflow:Train Step: 7939, loss: 0.010646221227943897, accuracy: 1.0
# INFO:tensorflow:Train Step: 7959, loss: 0.01289354171603918, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 7979, loss: 0.0033220385666936636, accuracy: 1.0
# INFO:tensorflow:Train Step: 7999, loss: 0.040106114000082016, accuracy: 0.9900000095367432
# INFO:tensorflow:Test Step: 7999, loss: 0.002300267107784748, accuracy: 0.9965000152587891
# INFO:tensorflow:Train Step: 8019, loss: 0.035511456429958344, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 8039, loss: 0.017008107155561447, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 8059, loss: 0.010325414128601551, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 8079, loss: 0.000498528650496155, accuracy: 1.0
# INFO:tensorflow:Train Step: 8099, loss: 0.0002691954141482711, accuracy: 1.0
# INFO:tensorflow:Test Step: 8099, loss: 0.0057428013533353806, accuracy: 0.9963999390602112
# INFO:tensorflow:Train Step: 8119, loss: 0.002623014384880662, accuracy: 1.0
# INFO:tensorflow:Train Step: 8139, loss: 0.01592930592596531, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 8159, loss: 0.0003005950420629233, accuracy: 1.0
# INFO:tensorflow:Train Step: 8179, loss: 0.0043878983706235886, accuracy: 1.0
# INFO:tensorflow:Train Step: 8199, loss: 0.012958714738488197, accuracy: 0.9900000095367432
# INFO:tensorflow:Test Step: 8199, loss: 0.00024279733770526946, accuracy: 0.9968999624252319
# INFO:tensorflow:Train Step: 8219, loss: 0.015197999775409698, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 8239, loss: 0.002814600709825754, accuracy: 1.0
# INFO:tensorflow:Train Step: 8259, loss: 0.02080792747437954, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 8279, loss: 0.019260089844465256, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 8299, loss: 0.0007639058749191463, accuracy: 1.0
# INFO:tensorflow:Test Step: 8299, loss: 0.0021387310698628426, accuracy: 0.9962999820709229
# INFO:tensorflow:Train Step: 8319, loss: 0.012516569346189499, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 8339, loss: 0.0006024850299581885, accuracy: 1.0
# INFO:tensorflow:Train Step: 8359, loss: 0.01068178378045559, accuracy: 1.0
# INFO:tensorflow:Train Step: 8379, loss: 0.0016099894419312477, accuracy: 1.0
# INFO:tensorflow:Train Step: 8399, loss: 0.0011862005339935422, accuracy: 1.0
# INFO:tensorflow:Test Step: 8399, loss: 0.0065111094154417515, accuracy: 0.9954999685287476
# INFO:tensorflow:Train Step: 8419, loss: 0.0015455360990017653, accuracy: 1.0
# INFO:tensorflow:Train Step: 8439, loss: 0.010632767342031002, accuracy: 1.0
# INFO:tensorflow:Train Step: 8459, loss: 0.020308053120970726, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 8479, loss: 0.002630348317325115, accuracy: 1.0
# INFO:tensorflow:Train Step: 8499, loss: 0.006783048622310162, accuracy: 1.0
# INFO:tensorflow:Test Step: 8499, loss: 0.0005823621177114546, accuracy: 0.9955999851226807
# INFO:tensorflow:Train Step: 8519, loss: 0.03176848962903023, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 8539, loss: 0.011756440624594688, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 8559, loss: 0.0004260524292476475, accuracy: 1.0
# INFO:tensorflow:Train Step: 8579, loss: 0.00027888151817023754, accuracy: 1.0
# INFO:tensorflow:Train Step: 8599, loss: 0.04456297308206558, accuracy: 0.9800000190734863
# INFO:tensorflow:Test Step: 8599, loss: 0.0012281564995646477, accuracy: 0.9959999322891235
# INFO:tensorflow:Train Step: 8619, loss: 0.016597989946603775, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 8639, loss: 0.02969946153461933, accuracy: 0.9800000190734863
# INFO:tensorflow:Train Step: 8659, loss: 0.0034227841533720493, accuracy: 1.0
# INFO:tensorflow:Train Step: 8679, loss: 0.02225608564913273, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 8699, loss: 0.005994134116917849, accuracy: 1.0
# INFO:tensorflow:Test Step: 8699, loss: 0.002554637147113681, accuracy: 0.9966999888420105
# INFO:tensorflow:Train Step: 8719, loss: 0.0341649167239666, accuracy: 0.9800000190734863
# INFO:tensorflow:Train Step: 8739, loss: 0.003548934357240796, accuracy: 1.0
# INFO:tensorflow:Train Step: 8759, loss: 0.0010587024735286832, accuracy: 1.0
# INFO:tensorflow:Train Step: 8779, loss: 0.02555568888783455, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 8799, loss: 0.0013896264135837555, accuracy: 1.0
# INFO:tensorflow:Test Step: 8799, loss: 0.008194384165108204, accuracy: 0.9962999820709229
# INFO:tensorflow:Train Step: 8819, loss: 0.00046128162648528814, accuracy: 1.0
# INFO:tensorflow:Train Step: 8839, loss: 0.0011182633461430669, accuracy: 1.0
# INFO:tensorflow:Train Step: 8859, loss: 0.007198767736554146, accuracy: 1.0
# INFO:tensorflow:Train Step: 8879, loss: 0.045060623437166214, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 8899, loss: 0.0006574217695742846, accuracy: 1.0
# INFO:tensorflow:Test Step: 8899, loss: 0.0002796644694171846, accuracy: 0.9961999654769897
# INFO:tensorflow:Train Step: 8919, loss: 0.002972506219521165, accuracy: 1.0
# INFO:tensorflow:Train Step: 8939, loss: 0.004113839007914066, accuracy: 1.0
# INFO:tensorflow:Train Step: 8959, loss: 0.0012735628988593817, accuracy: 1.0
# INFO:tensorflow:Train Step: 8979, loss: 0.005735019221901894, accuracy: 1.0
# INFO:tensorflow:Train Step: 8999, loss: 0.008668307214975357, accuracy: 0.9900000095367432
# INFO:tensorflow:Test Step: 8999, loss: 0.020937491208314896, accuracy: 0.9966999292373657
# INFO:tensorflow:Train Step: 9019, loss: 0.001390941091813147, accuracy: 1.0
# INFO:tensorflow:Train Step: 9039, loss: 0.05472327768802643, accuracy: 0.9800000190734863
# INFO:tensorflow:Train Step: 9059, loss: 0.0006536436849273741, accuracy: 1.0
# INFO:tensorflow:Train Step: 9079, loss: 0.022257523611187935, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 9099, loss: 0.0006597748142667115, accuracy: 1.0
# INFO:tensorflow:Test Step: 9099, loss: 9.006597974803299e-05, accuracy: 0.9968000054359436
# INFO:tensorflow:Train Step: 9119, loss: 0.011272095143795013, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 9139, loss: 0.0421961210668087, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 9159, loss: 0.0006629705312661827, accuracy: 1.0
# INFO:tensorflow:Train Step: 9179, loss: 0.0015157595044001937, accuracy: 1.0
# INFO:tensorflow:Train Step: 9199, loss: 0.0024550592061132193, accuracy: 1.0
# INFO:tensorflow:Test Step: 9199, loss: 0.019971663132309914, accuracy: 0.9965000152587891
# INFO:tensorflow:Train Step: 9219, loss: 0.0009235660545527935, accuracy: 1.0
# INFO:tensorflow:Train Step: 9239, loss: 0.002994910581037402, accuracy: 1.0
# INFO:tensorflow:Train Step: 9259, loss: 0.012363141402602196, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 9279, loss: 0.007151124533265829, accuracy: 1.0
# INFO:tensorflow:Train Step: 9299, loss: 0.0024854657240211964, accuracy: 1.0
# INFO:tensorflow:Test Step: 9299, loss: 0.008483276702463627, accuracy: 0.9957999587059021
# INFO:tensorflow:Train Step: 9319, loss: 0.0010033331345766783, accuracy: 1.0
# INFO:tensorflow:Train Step: 9339, loss: 0.017986644059419632, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 9359, loss: 0.009665907360613346, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 9379, loss: 0.01761719025671482, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 9399, loss: 0.0004159390809945762, accuracy: 1.0
# INFO:tensorflow:Test Step: 9399, loss: 0.000136114438646473, accuracy: 0.9964999556541443
# INFO:tensorflow:Train Step: 9419, loss: 0.004093562252819538, accuracy: 1.0
# INFO:tensorflow:Train Step: 9439, loss: 0.02169257588684559, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 9459, loss: 0.0005031917244195938, accuracy: 1.0
# INFO:tensorflow:Train Step: 9479, loss: 0.0025912439450621605, accuracy: 1.0
# INFO:tensorflow:Train Step: 9499, loss: 0.05879279971122742, accuracy: 0.9800000190734863
# INFO:tensorflow:Test Step: 9499, loss: 0.007348214276134968, accuracy: 0.996399998664856
# INFO:tensorflow:Train Step: 9519, loss: 0.0006034860271029174, accuracy: 1.0
# INFO:tensorflow:Train Step: 9539, loss: 0.020532524213194847, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 9559, loss: 0.0076691387221217155, accuracy: 1.0
# INFO:tensorflow:Train Step: 9579, loss: 0.024070333689451218, accuracy: 0.9800000190734863
# INFO:tensorflow:Train Step: 9599, loss: 0.0014372622827067971, accuracy: 1.0
# INFO:tensorflow:Test Step: 9599, loss: 0.00025205276324413717, accuracy: 0.9968000054359436
# INFO:tensorflow:Train Step: 9619, loss: 0.003345271572470665, accuracy: 1.0
# INFO:tensorflow:Train Step: 9639, loss: 0.013659084215760231, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 9659, loss: 0.0021712081506848335, accuracy: 1.0
# INFO:tensorflow:Train Step: 9679, loss: 0.0007836574222892523, accuracy: 1.0
# INFO:tensorflow:Train Step: 9699, loss: 0.017298752442002296, accuracy: 0.9900000095367432
# INFO:tensorflow:Test Step: 9699, loss: 0.00018126930808648467, accuracy: 0.9967999458312988
# INFO:tensorflow:Train Step: 9719, loss: 0.027797548100352287, accuracy: 0.9800000190734863
# INFO:tensorflow:Train Step: 9739, loss: 0.00014591607032343745, accuracy: 1.0
# INFO:tensorflow:Train Step: 9759, loss: 0.0007292093941941857, accuracy: 1.0
# INFO:tensorflow:Train Step: 9779, loss: 0.0012680618092417717, accuracy: 1.0
# INFO:tensorflow:Train Step: 9799, loss: 0.009696361608803272, accuracy: 0.9900000095367432
# INFO:tensorflow:Test Step: 9799, loss: 0.00026702723698690534, accuracy: 0.9966999888420105
# INFO:tensorflow:Train Step: 9819, loss: 0.0016143849352374673, accuracy: 1.0
# INFO:tensorflow:Train Step: 9839, loss: 0.03229052200913429, accuracy: 0.9800000190734863
# INFO:tensorflow:Train Step: 9859, loss: 0.0014807800762355328, accuracy: 1.0
# INFO:tensorflow:Train Step: 9879, loss: 0.0033395648933947086, accuracy: 1.0
# INFO:tensorflow:Train Step: 9899, loss: 0.00799050834029913, accuracy: 0.9900000095367432
# INFO:tensorflow:Test Step: 9899, loss: 0.00014457177894655615, accuracy: 0.9969999194145203
# INFO:tensorflow:Train Step: 9919, loss: 0.008927482180297375, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 9939, loss: 0.016071122139692307, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 9959, loss: 0.007650530897080898, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 9979, loss: 0.02191266603767872, accuracy: 0.9900000095367432
# INFO:tensorflow:Train Step: 9999, loss: 0.051070913672447205, accuracy: 0.9800000190734863
# INFO:tensorflow:Test Step: 9999, loss: 0.0023495377972722054, accuracy: 0.9969000220298767
